# %%
import pandas as pd

df1 = pd.read_csv('/kaggle/input/topfacialregions/top_facial_regions_dataset.csv')
df2 = pd.read_csv('/kaggle/input/mfcc-top-features/MFCC_important_feature.csv')

# %%
print("Face CSV file:")
df1.head()
# Out:
# Face CSV file:
#    lipsUpperOuter_61  lipsUpperOuter_185  lipsUpperOuter_40  \
# 0          -0.796998           -0.783761          -0.854249
# 1          -0.642420           -0.637615          -0.723670
# 2          -0.788563           -0.800038          -0.889967
# 3          -2.699764           -2.638462          -2.861563
# 4          -0.570210           -0.582949          -0.669734
#
#    lipsUpperOuter_39  lipsUpperOuter_37  lipsUpperOuter_0  lipsUpperOuter_267  \
# 0          -1.005285          -1.792751        -29.106225            2.036443
# 1          -0.889811          -1.550794         -6.475804            3.615617
# 2          -1.072733          -2.086448          9.135111            1.369078
# 3          -3.422442          -7.638168         12.177414            3.140405
# 4          -0.824996          -1.521187        -13.638438            2.015914
#
#    lipsUpperOuter_269  lipsUpperOuter_270  lipsUpperOuter_409  ...  \
# 0            1.081125            0.908469            0.832174  ...
# 1            1.600363            1.280204            1.130504  ...
# 2            0.754315            0.631121            0.568725  ...
# 3            1.905193            1.654674            1.538375  ...
# 4            0.966277            0.770261            0.666191  ...
#
#    leftCheek_436  leftCheek_416  leftCheek_432  leftCheek_434  leftCheek_422  \
# 0       0.436471       0.406742       0.624146       0.561062       0.876275
# 1       0.617774       0.618373       0.926578       0.853487       1.379093
# 2       0.186183       0.158452       0.354429       0.293867       0.554730
# 3       0.778128       0.764361       1.228064       1.113862       1.775543
# 4       0.255883       0.230079       0.448418       0.385427       0.694891
#
#    leftCheek_430  leftCheek_364  leftCheek_394  leftCheek_371  is_stroke_face
# 0       0.871828       0.710128       0.976405      -0.134716               1
# 1       1.413742       1.122774       1.634850      -0.205107               1
# 2       0.543838       0.411882       0.618886      -0.595886               1
# 3       1.800757       1.456326       2.028305      -0.741644               1
# 4       0.692805       0.522984       0.789427      -0.455395               1
#
# [5 rows x 116 columns]

# %%
print("\nMFCC CSV file:")
df2.head()
# Out:
# MFCC CSV file:
#            0        36        82        49        12        24        14  \
# 0 -398.97055  0.643070 -0.082618 -0.626069 -2.605149  0.169234  5.158936
# 1 -232.39255 -2.081796  0.518272 -0.584924 -1.054728 -3.284457  8.884685
# 2 -466.48450 -0.686953  0.154127  1.862350  5.793727  0.856521  3.335157
# 3 -466.73505  0.354227  0.893241  2.739482  6.860754  1.779491 -1.749699
# 4 -426.44970 -0.146068  0.319562  0.793730  3.329647 -1.323783  2.997393
#
#          45        35       117  ...        17        80        75       122  \
# 0 -1.069310  0.996082 -0.107622  ... -0.403323  0.584761  0.796598 -0.262222
# 1  3.845485  0.056364  0.169014  ... -0.775419 -0.896011 -2.070404 -0.022294
# 2  1.209667  2.896147  0.387918  ...  1.396552  0.450076  0.233947  0.154122
# 3  2.230495  0.916992  0.521781  ...  2.674563  0.371232  0.142578  0.071348
# 4  0.707389  1.125068 -0.113349  ... -1.877208  0.686355  1.219750  0.138273
#
#         121        73       127       125       110  class
# 0 -0.650705  0.301149 -0.188446 -0.257223  1.308860      1
# 1  0.166091 -0.027320 -0.390595  0.264451  0.036457      1
# 2  0.237405  0.607886  0.285212 -0.073312  0.899342      1
# 3 -0.274066  0.610250 -0.105873  0.000649  0.777924      1
# 4  0.070115  2.272153  0.120445 -0.295089  1.216608      1
#
# [5 rows x 129 columns]

# %%
df2.head()
# Out:
#            0        36        82        49        12        24        14  \
# 0 -398.97055  0.643070 -0.082618 -0.626069 -2.605149  0.169234  5.158936
# 1 -232.39255 -2.081796  0.518272 -0.584924 -1.054728 -3.284457  8.884685
# 2 -466.48450 -0.686953  0.154127  1.862350  5.793727  0.856521  3.335157
# 3 -466.73505  0.354227  0.893241  2.739482  6.860754  1.779491 -1.749699
# 4 -426.44970 -0.146068  0.319562  0.793730  3.329647 -1.323783  2.997393
#
#          45        35       117  ...        17        80        75       122  \
# 0 -1.069310  0.996082 -0.107622  ... -0.403323  0.584761  0.796598 -0.262222
# 1  3.845485  0.056364  0.169014  ... -0.775419 -0.896011 -2.070404 -0.022294
# 2  1.209667  2.896147  0.387918  ...  1.396552  0.450076  0.233947  0.154122
# 3  2.230495  0.916992  0.521781  ...  2.674563  0.371232  0.142578  0.071348
# 4  0.707389  1.125068 -0.113349  ... -1.877208  0.686355  1.219750  0.138273
#
#         121        73       127       125       110  class
# 0 -0.650705  0.301149 -0.188446 -0.257223  1.308860      1
# 1  0.166091 -0.027320 -0.390595  0.264451  0.036457      1
# 2  0.237405  0.607886  0.285212 -0.073312  0.899342      1
# 3 -0.274066  0.610250 -0.105873  0.000649  0.777924      1
# 4  0.070115  2.272153  0.120445 -0.295089  1.216608      1
#
# [5 rows x 129 columns]

# %%
df1.shape
# Out:
# (1996, 116)

# %%
df1['is_stroke_face'].value_counts()
# Out:
# is_stroke_face
# 1    998
# 0    998
# Name: count, dtype: int64

# %%
df2.shape
# Out:
# (4314, 129)

# %%
df2['class'].value_counts()
# Out:
# class
# 0    2953
# 1    1361
# Name: count, dtype: int64

# %%
# Trim 6 rows
def trim_rows_balanced(df, target_col, rows_to_remove):
    class_counts = df[target_col].value_counts()
    total = class_counts.sum()
    
    
    remove_counts = (class_counts / total * rows_to_remove).round().astype(int)
    
   
    while remove_counts.sum() != rows_to_remove:
        diff = rows_to_remove - remove_counts.sum()
        max_class = remove_counts.idxmax() if diff > 0 else remove_counts.idxmin()
        remove_counts[max_class] += 1 if diff > 0 else -1

  
    indices_to_remove = []
    for cls, n_remove in remove_counts.items():
        indices = df[df[target_col] == cls].sample(n=n_remove, random_state=42).index
        indices_to_remove.extend(indices)

    return df.drop(index=indices_to_remove)

df1_trimmed = trim_rows_balanced(df1, target_col='is_stroke_face', rows_to_remove=6)

# Trim df2 to 1990 rows with equal class distribution
def balance_to_n_rows(df, target_col, total_rows):
    unique_classes = df[target_col].unique()
    n_classes = len(unique_classes)
    n_per_class = total_rows // n_classes

    # Sample n_per_class from each class
    balanced_df = df.groupby(target_col).sample(n=n_per_class, random_state=42)
    
    return balanced_df

df2_trimmed = balance_to_n_rows(df2, target_col='class', total_rows=1990)


print("df1_trimmed shape:", df1_trimmed.shape)
print("df1_trimmed class distribution:\n", df1_trimmed['is_stroke_face'].value_counts())

print("\ndf2_trimmed shape:", df2_trimmed.shape)
print("df2_trimmed class distribution:\n", df2_trimmed['class'].value_counts())
# Out:
# df1_trimmed shape: (1990, 116)
# df1_trimmed class distribution:
#  is_stroke_face
# 1    995
# 0    995
# Name: count, dtype: int64
#
# df2_trimmed shape: (1990, 129)
# df2_trimmed class distribution:
#  class
# 0    995
# 1    995
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

# Separate features and targets
X_df1 = df1_trimmed.drop(columns=['is_stroke_face'])
y_df1 = df1_trimmed['is_stroke_face']

X_df2 = df2_trimmed.drop(columns=['class'])
y_df2 = df2_trimmed['class']

# Scaling
scaler = MinMaxScaler()


X_df1_scaled = scaler.fit_transform(X_df1)
X_df2_scaled = scaler.fit_transform(X_df2)


X_df1_scaled = pd.DataFrame(X_df1_scaled, columns=X_df1.columns)
X_df2_scaled = pd.DataFrame(X_df2_scaled, columns=X_df2.columns)


df1_scaled = pd.concat([X_df1_scaled, y_df1.reset_index(drop=True)], axis=1)
df2_scaled = pd.concat([X_df2_scaled, y_df2.reset_index(drop=True)], axis=1)

# %%
df1_scaled.head()
# Out:
#    lipsUpperOuter_61  lipsUpperOuter_185  lipsUpperOuter_40  \
# 0           0.881892            0.447948           0.915568
# 1           0.883030            0.450550           0.915943
# 2           0.881954            0.447658           0.915465
# 3           0.867880            0.414930           0.909804
# 4           0.883562            0.451523           0.916097
#
#    lipsUpperOuter_39  lipsUpperOuter_37  lipsUpperOuter_0  lipsUpperOuter_267  \
# 0           0.562871           0.089069          0.589250            0.217464
# 1           0.563874           0.089116          0.591155            0.221953
# 2           0.562286           0.089012          0.592470            0.215567
# 3           0.541894           0.087934          0.592726            0.220602
# 4           0.564436           0.089122          0.590552            0.217406
#
#    lipsUpperOuter_269  lipsUpperOuter_270  lipsUpperOuter_409  ...  \
# 0            0.307646            0.042146            0.067414  ...
# 1            0.311974            0.050797            0.079354  ...
# 2            0.304922            0.035691            0.056870  ...
# 3            0.314515            0.059513            0.095679  ...
# 4            0.306689            0.038929            0.060771  ...
#
#    leftCheek_436  leftCheek_416  leftCheek_432  leftCheek_434  leftCheek_422  \
# 0       0.381357       0.312092       0.288162       0.295674       0.105066
# 1       0.434563       0.388227       0.345782       0.362441       0.135429
# 2       0.307906       0.222769       0.236775       0.234668       0.085650
# 3       0.481622       0.440747       0.403222       0.421890       0.159369
# 4       0.328361       0.248537       0.254682       0.255573       0.094113
#
#    leftCheek_430  leftCheek_364  leftCheek_394  leftCheek_371  is_stroke_face
# 0       0.106496       0.155501       0.472941       0.476629               1
# 1       0.140510       0.204020       0.479105       0.469896               1
# 2       0.085909       0.120433       0.469594       0.432517               1
# 3       0.164802       0.243240       0.482789       0.418575               1
# 4       0.095259       0.133496       0.471190       0.445955               1
#
# [5 rows x 116 columns]

# %%
df2_scaled.head()
# Out:
#           0        36        82        49        12        24        14  \
# 0  0.601901  0.161727  0.444183  0.495212  0.444966  0.479833  0.393427
# 1  0.587872  0.300513  0.239001  0.425960  0.596527  0.547407  0.409081
# 2  0.714571  0.326082  0.447749  0.442264  0.440363  0.388346  0.477000
# 3  0.553675  0.272393  0.430650  0.196894  0.602634  0.396230  0.672127
# 4  0.622697  0.209115  0.461815  0.178129  0.535009  0.375684  0.594596
#
#          45        35       117  ...        17        80        75       122  \
# 0  0.563670  0.296904  0.617759  ...  0.221140  0.501655  0.343657  0.407719
# 1  0.472166  0.308389  0.543574  ...  0.243041  0.611149  0.387481  0.350176
# 2  0.633058  0.312579  0.592325  ...  0.111436  0.597637  0.387725  0.407714
# 3  0.311784  0.317965  0.560966  ...  0.261425  0.341567  0.369552  0.327748
# 4  0.273127  0.313362  0.432875  ...  0.323051  0.541460  0.455690  0.295203
#
#         121        73       127       125       110  class
# 0  0.363788  0.557478  0.647691  0.466653  0.515454      0
# 1  0.290886  0.470372  0.459253  0.535039  0.587362      0
# 2  0.434392  0.475345  0.498591  0.492717  0.549043      0
# 3  0.539348  0.569959  0.442423  0.504189  0.694026      0
# 4  0.479381  0.576589  0.345040  0.487118  0.639558      0
#
# [5 rows x 129 columns]

# %%
df2_scaled = df2_scaled.rename(columns={'class': 'is_stroke_face'})

# %%
df2_scaled.head()
# Out:
#           0        36        82        49        12        24        14  \
# 0  0.601901  0.161727  0.444183  0.495212  0.444966  0.479833  0.393427
# 1  0.587872  0.300513  0.239001  0.425960  0.596527  0.547407  0.409081
# 2  0.714571  0.326082  0.447749  0.442264  0.440363  0.388346  0.477000
# 3  0.553675  0.272393  0.430650  0.196894  0.602634  0.396230  0.672127
# 4  0.622697  0.209115  0.461815  0.178129  0.535009  0.375684  0.594596
#
#          45        35       117  ...        17        80        75       122  \
# 0  0.563670  0.296904  0.617759  ...  0.221140  0.501655  0.343657  0.407719
# 1  0.472166  0.308389  0.543574  ...  0.243041  0.611149  0.387481  0.350176
# 2  0.633058  0.312579  0.592325  ...  0.111436  0.597637  0.387725  0.407714
# 3  0.311784  0.317965  0.560966  ...  0.261425  0.341567  0.369552  0.327748
# 4  0.273127  0.313362  0.432875  ...  0.323051  0.541460  0.455690  0.295203
#
#         121        73       127       125       110  is_stroke_face
# 0  0.363788  0.557478  0.647691  0.466653  0.515454               0
# 1  0.290886  0.470372  0.459253  0.535039  0.587362               0
# 2  0.434392  0.475345  0.498591  0.492717  0.549043               0
# 3  0.539348  0.569959  0.442423  0.504189  0.694026               0
# 4  0.479381  0.576589  0.345040  0.487118  0.639558               0
#
# [5 rows x 129 columns]

# %%
target = df2_scaled['is_stroke_face']
df2_scaled = df2_scaled.iloc[:, :-14]
df2_scaled['is_stroke_face'] = target

# %%
df2_scaled.head()
# Out:
#           0        36        82        49        12        24        14  \
# 0  0.601901  0.161727  0.444183  0.495212  0.444966  0.479833  0.393427
# 1  0.587872  0.300513  0.239001  0.425960  0.596527  0.547407  0.409081
# 2  0.714571  0.326082  0.447749  0.442264  0.440363  0.388346  0.477000
# 3  0.553675  0.272393  0.430650  0.196894  0.602634  0.396230  0.672127
# 4  0.622697  0.209115  0.461815  0.178129  0.535009  0.375684  0.594596
#
#          45        35       117  ...        11        27        91        84  \
# 0  0.563670  0.296904  0.617759  ...  0.459173  0.321483  0.307755  0.488477
# 1  0.472166  0.308389  0.543574  ...  0.464221  0.343114  0.319049  0.533589
# 2  0.633058  0.312579  0.592325  ...  0.290786  0.240714  0.419508  0.524598
# 3  0.311784  0.317965  0.560966  ...  0.483063  0.448144  0.516492  0.211770
# 4  0.273127  0.313362  0.432875  ...  0.441071  0.341520  0.446190  0.361633
#
#          25         9        13        92        18  is_stroke_face
# 0  0.229315  0.587849  0.520666  0.421341  0.269000               0
# 1  0.264818  0.479138  0.548649  0.362116  0.343410               0
# 2  0.246301  0.394052  0.532937  0.513566  0.244737               0
# 3  0.392312  0.597635  0.570994  0.442014  0.253837               0
# 4  0.306473  0.522765  0.329593  0.493005  0.269006               0
#
# [5 rows x 116 columns]

# %%
df1_0 = df1_scaled[df1_scaled['is_stroke_face'] == 0]
df1_1 = df1_scaled[df1_scaled['is_stroke_face'] == 1]

df2_0 = df2_scaled[df2_scaled['is_stroke_face'] == 0]
df2_1 = df2_scaled[df2_scaled['is_stroke_face'] == 1]

# %%
df1_0
# Out:
#       lipsUpperOuter_61  lipsUpperOuter_185  lipsUpperOuter_40  \
# 995            0.882842            0.449948           0.915848
# 996            0.879978            0.443797           0.915005
# 997            0.504608            0.000000           0.793527
# 998            0.884528            0.454050           0.916574
# 999            0.883549            0.451533           0.916081
# ...                 ...                 ...                ...
# 1985           0.882796            0.449847           0.915864
# 1986           0.880846            0.444994           0.914968
# 1987           0.882660            0.449372           0.915746
# 1988           0.886155            0.457919           0.917246
# 1989           0.879640            0.442448           0.914590
#
#       lipsUpperOuter_39  lipsUpperOuter_37  lipsUpperOuter_0  \
# 995            0.563706           0.089092          0.587644
# 996            0.561515           0.089044          0.590085
# 997            1.000000           0.090398          0.591886
# 998            0.566262           0.089172          0.592754
# 999            0.564358           0.089120          0.590650
# ...                 ...                ...               ...
# 1985           0.563889           0.089093          0.594838
# 1986           0.560465           0.088951          0.600304
# 1987           0.563339           0.089058          0.593250
# 1988           0.568661           0.089310          0.591610
# 1989           0.559323           0.088852          0.592542
#
#       lipsUpperOuter_267  lipsUpperOuter_269  lipsUpperOuter_270  \
# 995             0.216884            0.306630            0.039441
# 996             0.218740            0.310219            0.050043
# 997             0.214899            0.304795            0.035302
# 998             0.214620            0.303334            0.031880
# 999             0.217985            0.307782            0.041585
# ...                  ...                 ...                 ...
# 1985            0.216008            0.305487            0.037206
# 1986            0.218115            0.308701            0.044114
# 1987            0.215953            0.305496            0.036845
# 1988            0.204228            1.000000            0.184543
# 1989            0.216647            0.307118            0.041175
#
#       lipsUpperOuter_409  ...  leftCheek_436  leftCheek_416  leftCheek_432  \
# 995             0.062317  ...       0.334900       0.253085       0.259114
# 996             0.082683  ...       0.409951       0.327875       0.313353
# 997             0.055496  ...       0.282483       0.170360       0.228686
# 998             0.050612  ...       0.284412       0.191220       0.218458
# 999             0.064951  ...       0.341064       0.256289       0.268580
# ...                  ...  ...            ...            ...            ...
# 1985            0.059380  ...       0.318882       0.231722       0.247051
# 1986            0.069576  ...       0.361540       0.279989       0.282382
# 1987            0.058223  ...       0.314380       0.219694       0.240051
# 1988            0.219161  ...       0.467372       0.368716       0.430560
# 1989            0.065680  ...       0.347202       0.258840       0.266165
#
#       leftCheek_434  leftCheek_422  leftCheek_430  leftCheek_364  \
# 995        0.259640       0.095615       0.096149       0.134457
# 996        0.313954       0.115358       0.113697       0.162361
# 997        0.217180       0.084102       0.083485       0.108849
# 998        0.214024       0.078245       0.078862       0.105903
# 999        0.268517       0.101164       0.102198       0.140380
# ...             ...            ...            ...            ...
# 1985       0.244967       0.090265       0.090586       0.125730
# 1986       0.283048       0.105149       0.105505       0.149023
# 1987       0.235566       0.086468       0.086159       0.117883
# 1988       0.407163       0.247307       0.236569       0.270838
# 1989       0.264385       0.096482       0.096038       0.134645
#
#       leftCheek_394  leftCheek_371  is_stroke_face
# 995        0.471263       0.448104               0
# 996        0.473790       0.475063               0
# 997        0.468950       0.401404               0
# 998        0.468410       0.437291               0
# 999        0.472282       0.439788               0
# ...             ...            ...             ...
# 1985       0.470362       0.439770               0
# 1986       0.472769       0.444256               0
# 1987       0.469523       0.440500               0
# 1988       0.508106       0.446149               0
# 1989       0.471051       0.448691               0
#
# [995 rows x 116 columns]

# %%
df1_1
# Out:
#      lipsUpperOuter_61  lipsUpperOuter_185  lipsUpperOuter_40  \
# 0             0.881892            0.447948           0.915568
# 1             0.883030            0.450550           0.915943
# 2             0.881954            0.447658           0.915465
# 3             0.867880            0.414930           0.909804
# 4             0.883562            0.451523           0.916097
# ..                 ...                 ...                ...
# 990           0.879066            0.441125           0.914371
# 991           0.856242            0.388623           0.904288
# 992           0.882639            0.449405           0.915757
# 993           0.880359            0.443743           0.914735
# 994           0.884217            0.453252           0.916453
#
#      lipsUpperOuter_39  lipsUpperOuter_37  lipsUpperOuter_0  \
# 0             0.562871           0.089069          0.589250
# 1             0.563874           0.089116          0.591155
# 2             0.562286           0.089012          0.592470
# 3             0.541894           0.087934          0.592726
# 4             0.564436           0.089122          0.590552
# ..                 ...                ...               ...
# 990           0.558387           0.088760          0.592278
# 991           0.505060           0.090872          0.591871
# 992           0.563371           0.089073          0.600807
# 993           0.559552           0.088893          0.593489
# 994           0.565907           0.089205          0.591374
#
#      lipsUpperOuter_267  lipsUpperOuter_269  lipsUpperOuter_270  \
# 0              0.217464            0.307646            0.042146
# 1              0.221953            0.311974            0.050797
# 2              0.215567            0.304922            0.035691
# 3              0.220602            0.314515            0.059513
# 4              0.217406            0.306689            0.038929
# ..                  ...                 ...                 ...
# 990            0.216365            0.306977            0.041326
# 991            0.214533            0.304244            0.034675
# 992            0.216773            0.306537            0.039505
# 993            0.217763            0.308659            0.044461
# 994            0.220168            0.308685            0.043396
#
#      lipsUpperOuter_409  ...  leftCheek_436  leftCheek_416  leftCheek_432  \
# 0              0.067414  ...       0.381357       0.312092       0.288162
# 1              0.079354  ...       0.434563       0.388227       0.345782
# 2              0.056870  ...       0.307906       0.222769       0.236775
# 3              0.095679  ...       0.481622       0.440747       0.403222
# 4              0.060771  ...       0.328361       0.248537       0.254682
# ..                  ...  ...            ...            ...            ...
# 990            0.066816  ...       0.372551       0.305050       0.288972
# 991            0.055653  ...       0.318211       0.222679       0.238487
# 992            0.062963  ...       0.334302       0.257129       0.266231
# 993            0.070583  ...       0.368041       0.288282       0.283332
# 994            0.068205  ...       0.349795       0.272790       0.271945
#
#      leftCheek_434  leftCheek_422  leftCheek_430  leftCheek_364  \
# 0         0.295674       0.105066       0.106496       0.155501
# 1         0.362441       0.135429       0.140510       0.204020
# 2         0.234668       0.085650       0.085909       0.120433
# 3         0.421890       0.159369       0.164802       0.243240
# 4         0.255573       0.094113       0.095259       0.133496
# ..             ...            ...            ...            ...
# 990       0.296598       0.106445       0.108986       0.158019
# 991       0.235000       0.083621       0.083327       0.115274
# 992       0.268692       0.101181       0.103394       0.145308
# 993       0.285108       0.104506       0.104852       0.149309
# 994       0.272536       0.101582       0.101904       0.143321
#
#      leftCheek_394  leftCheek_371  is_stroke_face
# 0         0.472941       0.476629               1
# 1         0.479105       0.469896               1
# 2         0.469594       0.432517               1
# 3         0.482789       0.418575               1
# 4         0.471190       0.445955               1
# ..             ...            ...             ...
# 990       0.473439       0.454337               1
# 991       0.468874       0.450953               1
# 992       0.472844       0.430758               1
# 993       0.472648       0.448172               1
# 994       0.472268       0.454073               1
#
# [995 rows x 116 columns]

# %%
df2_0
# Out:
#             0        36        82        49        12        24        14  \
# 0    0.601901  0.161727  0.444183  0.495212  0.444966  0.479833  0.393427
# 1    0.587872  0.300513  0.239001  0.425960  0.596527  0.547407  0.409081
# 2    0.714571  0.326082  0.447749  0.442264  0.440363  0.388346  0.477000
# 3    0.553675  0.272393  0.430650  0.196894  0.602634  0.396230  0.672127
# 4    0.622697  0.209115  0.461815  0.178129  0.535009  0.375684  0.594596
# ..        ...       ...       ...       ...       ...       ...       ...
# 990  0.557765  0.278812  0.584517  0.363922  0.626515  0.363806  0.582670
# 991  0.536053  0.373037  0.148104  0.324416  0.611683  0.426399  0.640730
# 992  0.560043  0.258513  0.450867  0.174921  0.507825  0.409288  0.766818
# 993  0.496719  0.377909  0.179681  0.341751  0.495080  0.583282  0.616961
# 994  0.658422  0.155760  0.568243  0.292136  0.661903  0.387217  0.763248
#
#            45        35       117  ...        11        27        91  \
# 0    0.563670  0.296904  0.617759  ...  0.459173  0.321483  0.307755
# 1    0.472166  0.308389  0.543574  ...  0.464221  0.343114  0.319049
# 2    0.633058  0.312579  0.592325  ...  0.290786  0.240714  0.419508
# 3    0.311784  0.317965  0.560966  ...  0.483063  0.448144  0.516492
# 4    0.273127  0.313362  0.432875  ...  0.441071  0.341520  0.446190
# ..        ...       ...       ...  ...       ...       ...       ...
# 990  0.265838  0.299996  0.460122  ...  0.508004  0.337739  0.421676
# 991  0.540224  0.346916  0.583112  ...  0.713290  0.523669  0.361233
# 992  0.339683  0.291326  0.519946  ...  0.373562  0.294273  0.449332
# 993  0.536586  0.365545  0.579716  ...  0.630378  0.497435  0.380910
# 994  0.258243  0.277916  0.610668  ...  0.445876  0.337121  0.472481
#
#            84        25         9        13        92        18  \
# 0    0.488477  0.229315  0.587849  0.520666  0.421341  0.269000
# 1    0.533589  0.264818  0.479138  0.548649  0.362116  0.343410
# 2    0.524598  0.246301  0.394052  0.532937  0.513566  0.244737
# 3    0.211770  0.392312  0.597635  0.570994  0.442014  0.253837
# 4    0.361633  0.306473  0.522765  0.329593  0.493005  0.269006
# ..        ...       ...       ...       ...       ...       ...
# 990  0.300375  0.332627  0.639614  0.638774  0.562490  0.365051
# 991  0.778607  0.419035  0.586031  0.631143  0.635412  0.344704
# 992  0.282655  0.282632  0.510043  0.325323  0.488541  0.310236
# 993  0.776203  0.403162  0.535123  0.893958  0.613005  0.354513
# 994  0.164993  0.304511  0.660587  0.591404  0.609054  0.370457
#
#      is_stroke_face
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 990               0
# 991               0
# 992               0
# 993               0
# 994               0
#
# [995 rows x 116 columns]

# %%
df2_1
# Out:
#              0        36        82        49        12        24        14  \
# 995   0.819082  0.290838  0.744252  0.284531  0.890334  0.301135  0.993970
# 996   0.674307  0.328412  0.447576  0.555618  0.468877  0.359979  0.408475
# 997   0.695828  0.321527  0.249122  0.442721  0.498995  0.477018  0.490896
# 998   0.172095  0.390778  0.244769  0.333911  0.879534  0.311035  0.945827
# 999   0.646274  0.254700  0.503502  0.466716  0.340445  0.405860  0.409791
# ...        ...       ...       ...       ...       ...       ...       ...
# 1985  0.299845  0.412766  0.622759  0.542525  0.435977  0.357269  0.514852
# 1986  0.284747  0.290262  0.354405  0.377543  0.382527  0.521134  0.394593
# 1987  0.266203  0.444500  0.452147  0.332369  0.699746  0.398028  0.613518
# 1988  0.345287  0.334235  0.368711  0.470087  0.325543  0.716560  0.450315
# 1989  0.431757  0.331684  0.539639  0.534085  0.193214  0.401295  0.448119
#
#             45        35       117  ...        11        27        91  \
# 995   0.371397  0.247930  0.882140  ...  0.332192  0.387419  0.677553
# 996   0.537148  0.371975  0.666632  ...  0.511766  0.399264  0.440616
# 997   0.475253  0.358492  0.629760  ...  0.604234  0.494357  0.381679
# 998   0.539364  0.331777  0.582611  ...  0.580586  0.477300  0.146578
# 999   0.494876  0.343248  0.607458  ...  0.454593  0.427335  0.411870
# ...        ...       ...       ...  ...       ...       ...       ...
# 1985  0.663493  0.366377  0.612998  ...  0.338543  0.349358  0.439307
# 1986  0.562829  0.294559  0.527903  ...  0.671879  0.743905  0.528848
# 1987  0.479861  0.387170  0.683759  ...  0.848236  0.430885  0.202521
# 1988  0.404119  0.247484  0.650464  ...  0.657727  0.728314  0.451768
# 1989  0.643419  0.270469  0.511901  ...  0.700721  0.302826  0.505259
#
#             84        25         9        13        92        18  \
# 995   0.030694  0.449485  0.743229  0.202025  0.801555  0.406447
# 996   0.445894  0.292214  0.503038  0.528512  0.409900  0.332866
# 997   0.433084  0.370948  0.571817  0.459734  0.612820  0.200592
# 998   0.578520  0.515323  0.848290  0.315452  0.522091  0.379434
# 999   0.492863  0.208850  0.522538  0.536393  0.446744  0.380701
# ...        ...       ...       ...       ...       ...       ...
# 1985  0.765839  0.311906  0.696821  0.626973  0.506900  0.441370
# 1986  0.619778  0.441602  0.551406  0.370138  0.494788  0.281690
# 1987  0.663878  0.429129  0.765889  0.687429  0.384180  0.426770
# 1988  0.631441  0.606243  0.458442  0.421260  0.532624  0.155878
# 1989  0.438976  0.286646  0.575910  0.634017  0.634397  0.383965
#
#       is_stroke_face
# 995                1
# 996                1
# 997                1
# 998                1
# 999                1
# ...              ...
# 1985               1
# 1986               1
# 1987               1
# 1988               1
# 1989               1
#
# [995 rows x 116 columns]

# %%
# Step 2: Match minimum count to ensure balance
min_0 = min(len(df1_0), len(df2_0))
min_1 = min(len(df1_1), len(df2_1))

# %%
import numpy as np

df1_aligned = pd.concat([
    df1_0.sample(min_0, random_state=42),
    df1_1.sample(min_1, random_state=42)
]).reset_index(drop=True)

df2_aligned = pd.concat([
    df2_0.sample(min_0, random_state=42),
    df2_1.sample(min_1, random_state=42)
]).reset_index(drop=True)

# %%
df1_aligned
# Out:
#       lipsUpperOuter_61  lipsUpperOuter_185  lipsUpperOuter_40  \
# 0              0.881497            0.447005           0.915419
# 1              0.884349            0.453643           0.916555
# 2              0.880459            0.443912           0.914705
# 3              0.879977            0.443349           0.914743
# 4              0.882871            0.449940           0.915862
# ...                 ...                 ...                ...
# 1985           0.883101            0.450797           0.915977
# 1986           0.884025            0.453071           0.916397
# 1987           0.877657            0.436991           0.913428
# 1988           0.882479            0.449352           0.915811
# 1989           0.885089            0.455695           0.916866
#
#       lipsUpperOuter_39  lipsUpperOuter_37  lipsUpperOuter_0  \
# 0              0.562442           0.089046          0.599456
# 1              0.566440           0.089235          0.591511
# 2              0.559279           0.088883          0.597812
# 3              0.560109           0.088943          0.596436
# 4              0.563838           0.089100          0.606309
# ...                 ...                ...               ...
# 1985           0.563851           0.089042          0.592241
# 1986           0.565446           0.089143          0.593625
# 1987           0.554019           0.088427          0.592217
# 1988           0.563732           0.089109          0.590797
# 1989           0.567151           0.089212          0.590751
#
#       lipsUpperOuter_267  lipsUpperOuter_269  lipsUpperOuter_270  \
# 0               0.216899            0.307311            0.042024
# 1               0.257357            0.317895            0.062424
# 2               0.218939            0.309832            0.046294
# 3               0.217974            0.308874            0.045449
# 4               0.216263            0.305617            0.037295
# ...                  ...                 ...                 ...
# 1985            0.214914            0.304035            0.033371
# 1986            0.215192            0.304024            0.033097
# 1987            0.216766            0.307621            0.041783
# 1988            0.218264            0.308484            0.043859
# 1989            0.215969            0.305474            0.036722
#
#       lipsUpperOuter_409  ...  leftCheek_436  leftCheek_416  leftCheek_432  \
# 0               0.067697  ...       0.351072       0.261286       0.269767
# 1               0.097017  ...       0.424714       0.346014       0.337789
# 2               0.072099  ...       0.375990       0.305358       0.299856
# 3               0.072414  ...       0.338425       0.230139       0.272893
# 4               0.059285  ...       0.309950       0.212667       0.241391
# ...                  ...  ...            ...            ...            ...
# 1985            0.052989  ...       0.327372       0.268211       0.252015
# 1986            0.052448  ...       0.317797       0.262166       0.248847
# 1987            0.065738  ...       0.358339       0.285275       0.281020
# 1988            0.069849  ...       0.383327       0.313878       0.292376
# 1989            0.058239  ...       0.354589       0.292693       0.269008
#
#       leftCheek_434  leftCheek_422  leftCheek_430  leftCheek_364  \
# 0          0.267545       0.098968       0.098105       0.136479
# 1          0.337303       0.134694       0.132908       0.183596
# 2          0.305224       0.114128       0.116277       0.165072
# 3          0.263014       0.103691       0.102280       0.135535
# 4          0.236092       0.088901       0.089009       0.121967
# ...             ...            ...            ...            ...
# 1985       0.263111       0.092613       0.096997       0.140555
# 1986       0.260574       0.093048       0.098189       0.142034
# 1987       0.286203       0.104483       0.106888       0.152990
# 1988       0.298720       0.107650       0.108714       0.156418
# 1989       0.279555       0.098345       0.102068       0.146390
#
#       leftCheek_394  leftCheek_371  is_stroke_face
# 0          0.471378       0.456044               0
# 1          0.477654       0.469387               0
# 2          0.474686       0.437578               0
# 3          0.472092       0.418712               0
# 4          0.470229       0.429093               0
# ...             ...            ...             ...
# 1985       0.471727       0.457836               1
# 1986       0.472100       0.449160               1
# 1987       0.473140       0.438049               1
# 1988       0.473260       0.474558               1
# 1989       0.472407       0.473589               1
#
# [1990 rows x 116 columns]

# %%
df2_aligned
# Out:
#              0        36        82        49        12        24        14  \
# 0     0.611594  0.220126  0.154731  0.413490  0.488616  0.429440  0.464829
# 1     0.662334  0.361508  0.270218  0.469425  0.459215  0.438418  0.417275
# 2     0.565330  0.268556  0.728078  0.456911  0.644323  0.282669  0.629909
# 3     0.597498  0.248174  0.600840  0.339701  0.640657  0.312991  0.638203
# 4     0.573523  0.279202  0.464033  0.260096  0.612185  0.364638  0.718606
# ...        ...       ...       ...       ...       ...       ...       ...
# 1985  0.380251  0.563553  0.546562  0.355671  0.489291  0.339684  0.682250
# 1986  0.569846  0.296530  0.562064  0.660726  0.212333  0.289133  0.583927
# 1987  0.453016  0.402205  0.634587  0.426584  0.302191  0.376723  0.579508
# 1988  0.552670  0.587792  0.462738  0.380199  0.589599  0.238638  0.712088
# 1989  0.549327  0.307140  0.515457  0.585906  0.151738  0.270965  0.561724
#
#             45        35       117  ...        11        27        91  \
# 0     0.841768  0.328106  0.572456  ...  0.379140  0.334422  0.326521
# 1     0.461199  0.310585  0.597168  ...  0.541308  0.536188  0.410318
# 2     0.377999  0.301302  0.170739  ...  0.516046  0.254443  0.627662
# 3     0.263998  0.283451  0.406706  ...  0.533066  0.286571  0.542048
# 4     0.414297  0.356783  0.676161  ...  0.569600  0.301296  0.432287
# ...        ...       ...       ...  ...       ...       ...       ...
# 1985  0.427880  0.490589  0.686801  ...  0.587932  0.271668  0.425414
# 1986  0.698546  0.260592  0.566550  ...  0.502429  0.335157  0.446662
# 1987  0.522939  0.332734  0.535051  ...  0.609938  0.384635  0.581066
# 1988  0.518218  0.480977  0.606597  ...  0.539548  0.316884  0.372413
# 1989  0.629268  0.317331  0.659754  ...  0.507614  0.309744  0.422081
#
#             84        25         9        13        92        18  \
# 0     0.271997  0.228532  0.542573  0.527410  0.507808  0.349536
# 1     0.586683  0.406060  0.578725  0.598045  0.493851  0.228838
# 2     0.380102  0.289067  0.682236  0.485760  0.818948  0.299901
# 3     0.314695  0.308923  0.710181  0.607736  0.654157  0.319261
# 4     0.273966  0.342941  0.623690  0.600344  0.525319  0.282365
# ...        ...       ...       ...       ...       ...       ...
# 1985  0.339502  0.249960  0.596243  0.603015  0.381252  0.178649
# 1986  0.426718  0.285511  0.536091  0.315461  0.452045  0.385430
# 1987  0.408202  0.323087  0.837567  0.783161  0.576953  0.471338
# 1988  0.546157  0.291912  0.512655  0.398494  0.449876  0.255187
# 1989  0.553066  0.276757  0.658081  0.352384  0.511216  0.331788
#
#       is_stroke_face
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 1985               1
# 1986               1
# 1987               1
# 1988               1
# 1989               1
#
# [1990 rows x 116 columns]

# %%
df1_aligned.to_csv("df1_aligned.csv", index=False)
df2_aligned.to_csv("df2_aligned.csv", index=False)

# %%
df1_aligned_suffled = df1_aligned.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df2_aligned_suffled = df2_aligned.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
#df1_aligned_suffled.to_csv("df1_aligned_suffled.csv", index=False)
#df2_aligned_suffled.to_csv("df2_aligned_suffled.csv", index=False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Step 3: Final check — aligned class-wise
y = df1_aligned_suffled['is_stroke_face'].values
# y = df1_aligned['is_stroke_face'].values
X_landmark = df1_aligned_suffled.drop(columns=['is_stroke_face']).values
X_mfcc = df2_aligned_suffled.drop(columns=['is_stroke_face']).values


# Stratified train-test split (no validation, no temp)
X_train_landmark, X_test_landmark, X_train_mfcc, X_test_mfcc, y_train, y_test = train_test_split(
    X_landmark, X_mfcc, y, test_size=0.3, stratify=y, random_state=42)


# Print sizes
print(f"Landmark Training set size: {len(X_train_landmark)}")
print(f"Mfcc Training set size: {len(X_train_mfcc)}")
print(f"Landmark Test set size: {len(X_test_landmark)}")
print(f"Mfcc Test set size: {len(X_test_mfcc)}")
print(f"CommonTarget for Train  size: {len(y_train)}")
print(f"CommonTarget for Test  size: {len(y_test)}")
# Out:
# Landmark Training set size: 1393
# Mfcc Training set size: 1393
# Landmark Test set size: 597
# Mfcc Test set size: 597
# CommonTarget for Train  size: 1393
# CommonTarget for Test  size: 597

# %%
X_train_landmark
# Out:
# array([[0.88102386, 0.4455055 , 0.91508992, ..., 0.13784134, 0.47141704,
#         0.45257504],
#        [0.87490109, 0.43129068, 0.91262465, ..., 0.22409334, 0.48056872,
#         0.45115686],
#        [0.87988414, 0.44248089, 0.91443442, ..., 0.13650298, 0.47149972,
#         0.42857566],
#        ...,
#        [0.88437076, 0.45381453, 0.91656269, ..., 0.13810809, 0.47182929,
#         0.44971481],
#        [0.88223406, 0.44833568, 0.91555574, ..., 0.12165897, 0.46974443,
#         0.45038056],
#        [0.88316967, 0.45067232, 0.91597771, ..., 0.15611205, 0.47412358,
#         0.42558012]])

# %%
X_mfcc
# Out:
# array([[0.57391841, 0.16563661, 0.70610725, ..., 0.67904058, 0.63671264,
#         0.36312751],
#        [0.37245056, 0.36729571, 0.74866592, ..., 0.72277558, 0.63142052,
#         0.31311962],
#        [0.20244176, 0.25602253, 0.26257495, ..., 0.68996079, 0.60618412,
#         0.33199216],
#        ...,
#        [0.15716301, 0.23305737, 0.3593029 , ..., 0.54189082, 0.68982134,
#         0.30611086],
#        [0.41236666, 0.6207822 , 0.45324505, ..., 0.48956959, 0.40981263,
#         0.28578177],
#        [0.57791919, 0.39919284, 0.33580836, ..., 0.5627198 , 0.73201723,
#         0.1736178 ]])

# %%
#X_mfcc_scaled

# %%
from tensorflow.keras.layers import Input, Conv1D, LSTM, Dropout, BatchNormalization, Dense, Concatenate
from tensorflow.keras.models import Model

# Inputs
input_landmark = Input(shape=(X_train_landmark.shape[1], 1))  
input_mfcc = Input(shape=(X_train_mfcc.shape[1], 1))        

# Landmark branch
x1 = Conv1D(32, 3, activation='relu', padding='same')(input_landmark)
x1 = BatchNormalization()(x1)
x1 = LSTM(64, return_sequences=True)(x1)
x1 = LSTM(64)(x1)
x1 = Dropout(0.3)(x1)

# MFCC branch
x2 = Conv1D(32, 3, activation='relu', padding='same')(input_mfcc)
x2 = BatchNormalization()(x2)
x2 = LSTM(64, return_sequences=True)(x2)
x2 = LSTM(64)(x2)
x2 = Dropout(0.3)(x2)

# Concatenation and classification
x = Concatenate()([x1, x2])
x = Dense(128, activation='relu')(x)
x = Dropout(0.4)(x)
x = Dense(64, activation='relu')(x)
output = Dense(1, activation='sigmoid')(x)

# Model
model2 = Model(inputs=[input_landmark, input_mfcc], outputs=output)

# %%
model2.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 115, 1)         │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ input_layer_3             │ (None, 115, 1)         │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_2 (Conv1D)         │ (None, 115, 32)        │            128 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv1d_3 (Conv1D)         │ (None, 115, 32)        │            128 │ input_layer_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 115, 32)        │            128 │ conv1d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 115, 32)        │            128 │ conv1d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_4 (LSTM)             │ (None, 115, 64)        │         24,832 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_6 (LSTM)             │ (None, 115, 64)        │         24,832 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_5 (LSTM)             │ (None, 64)             │         33,024 │ lstm_4[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lstm_7 (LSTM)             │ (None, 64)             │         33,024 │ lstm_6[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_3 (Dropout)       │ (None, 64)             │              0 │ lstm_5[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 64)             │              0 │ lstm_7[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 128)            │              0 │ dropout_3[0][0],       │
# │ (Concatenate)             │                        │                │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 128)            │         16,512 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 128)            │              0 │ dense_3[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 64)             │          8,256 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 1)              │             65 │ dense_4[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 141,057 (551.00 KB)
#  Trainable params: 140,929 (550.50 KB)
#  Non-trainable params: 128 (512.00 B)

# %%
from tensorflow.keras.utils import plot_model
# Plot and save
plot_model(model2, to_file="model_architecture.png", show_shapes=True, show_layer_names=True)

# %%
def generate_mixed_data(X_landmark, X_mfcc, y, full_range=(0.1,1), landmark_range=(0.2,0.3)):
    total = len(X_landmark)
    
    # Random ratios
    full_input_ratio = np.random.uniform(*full_range)
    landmark_only_ratio = np.random.uniform(*landmark_range)
    mfcc_only_ratio = 1.0 - full_input_ratio - landmark_only_ratio

    # Fix if mfcc_only goes negative
    if mfcc_only_ratio < 0:
        mfcc_only_ratio = 0
        total_ratio = full_input_ratio + landmark_only_ratio
        full_input_ratio /= total_ratio
        landmark_only_ratio /= total_ratio

    # Calculate sizes
    n_full = int(full_input_ratio * total)
    n_landmark_only = int(landmark_only_ratio * total)
    n_mfcc_only = total - n_full - n_landmark_only  # Ensure total samples match

    # Shuffle
    indices = np.random.permutation(total)
    X_landmark = X_landmark[indices]
    X_mfcc = X_mfcc[indices]
    y = y[indices]

    # subsets
    X_landmark_full = X_landmark[:n_full]
    X_mfcc_full = X_mfcc[:n_full]
    y_full = y[:n_full]

    X_landmark_lo = X_landmark[n_full:n_full+n_landmark_only]
    X_mfcc_lo = np.zeros_like(X_mfcc[n_full:n_full+n_landmark_only])
    y_lo = y[n_full:n_full+n_landmark_only]

    X_landmark_mo = np.zeros_like(X_landmark[n_full+n_landmark_only:])
    X_mfcc_mo = X_mfcc[n_full+n_landmark_only:]
    y_mo = y[n_full+n_landmark_only:]

    # Combine
    X_landmark_mixed = np.concatenate([X_landmark_full, X_landmark_lo, X_landmark_mo])
    X_mfcc_mixed = np.concatenate([X_mfcc_full, X_mfcc_lo, X_mfcc_mo])
    y_mixed = np.concatenate([y_full, y_lo, y_mo])

    # Return data and ratios
    return X_landmark_mixed, X_mfcc_mixed, y_mixed, full_input_ratio, landmark_only_ratio, mfcc_only_ratio

# %%
import datetime
from tensorflow.keras.callbacks import TensorBoard
import tensorflow as tf

#TensorBoard log directory
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

#writer 
writer = tf.summary.create_file_writer(log_dir)

# Compile 
model2.compile(optimizer='adam',
               loss='binary_crossentropy',
               metrics=['accuracy'])

num_epochs = 500

for epoch in range(num_epochs):
    print(f"\nEpoch {epoch + 1}")
    
    # Generate new mixed data and ratios
    X_lm_mixed, X_mfcc_mixed, y_mixed, full_r, landmark_r, mfcc_r = generate_mixed_data(
        X_train_landmark, X_train_mfcc, y_train
    )
    
    # Print input ratios
    print(f"Ratios - Full Input: {full_r:.2f}, Landmark Only: {landmark_r:.2f}, MFCC Only: {mfcc_r:.2f}")
    
    # Train for 1 epoch
    history = model2.fit(
        [X_lm_mixed, X_mfcc_mixed], y_mixed,
        batch_size=32, epochs=1, verbose=0
    )
    
    # Extract and print loss and accuracy
    epoch_loss = history.history['loss'][0]
    epoch_acc = history.history['accuracy'][0]
    
    print(f"Loss: {epoch_loss:.4f} | Accuracy: {epoch_acc:.4f}")
    
    # 4. Log metrics to TensorBoard
    with writer.as_default():
        tf.summary.scalar("Loss", epoch_loss, step=epoch)
        tf.summary.scalar("Accuracy", epoch_acc, step=epoch)
# Out:
# Epoch 1
# Ratios - Full Input: 0.49, Landmark Only: 0.23, MFCC Only: 0.28
# Loss: 0.6846 | Accuracy: 0.5614
#
# Epoch 2
# Ratios - Full Input: 0.47, Landmark Only: 0.29, MFCC Only: 0.23
# Loss: 0.6685 | Accuracy: 0.5966
#
# Epoch 3
# Ratios - Full Input: 0.53, Landmark Only: 0.24, MFCC Only: 0.23
# Loss: 0.6154 | Accuracy: 0.6762
#
# Epoch 4
# Ratios - Full Input: 0.64, Landmark Only: 0.28, MFCC Only: 0.08
# Loss: 0.5887 | Accuracy: 0.6956
#
# Epoch 5
# Ratios - Full Input: 0.35, Landmark Only: 0.30, MFCC Only: 0.36
# Loss: 0.6272 | Accuracy: 0.6590
#
# Epoch 6
# Ratios - Full Input: 0.64, Landmark Only: 0.25, MFCC Only: 0.11
# Loss: 0.5808 | Accuracy: 0.7042
#
# Epoch 7
# Ratios - Full Input: 0.43, Landmark Only: 0.29, MFCC Only: 0.29
# Loss: 0.5693 | Accuracy: 0.7251
#
# Epoch 8
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.5454 | Accuracy: 0.7408
#
# Epoch 9
# Ratios - Full Input: 0.36, Landmark Only: 0.26, MFCC Only: 0.38
# Loss: 0.5774 | Accuracy: 0.7330
#
# Epoch 10
# Ratios - Full Input: 0.33, Landmark Only: 0.28, MFCC Only: 0.39
# Loss: 0.5499 | Accuracy: 0.7258
#
# Epoch 11
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.5256 | Accuracy: 0.7358
#
# Epoch 12
# Ratios - Full Input: 0.14, Landmark Only: 0.30, MFCC Only: 0.56
# Loss: 0.5744 | Accuracy: 0.6999
#
# Epoch 13
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.5124 | Accuracy: 0.7509
#
# Epoch 14
# Ratios - Full Input: 0.18, Landmark Only: 0.29, MFCC Only: 0.53
# Loss: 0.5237 | Accuracy: 0.7330
#
# Epoch 15
# Ratios - Full Input: 0.74, Landmark Only: 0.25, MFCC Only: 0.01
# Loss: 0.4470 | Accuracy: 0.7897
#
# Epoch 16
# Ratios - Full Input: 0.62, Landmark Only: 0.25, MFCC Only: 0.13
# Loss: 0.4882 | Accuracy: 0.7703
#
# Epoch 17
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.4845 | Accuracy: 0.7782
#
# Epoch 18
# Ratios - Full Input: 0.59, Landmark Only: 0.27, MFCC Only: 0.14
# Loss: 0.4568 | Accuracy: 0.7846
#
# Epoch 19
# Ratios - Full Input: 0.73, Landmark Only: 0.27, MFCC Only: 0.00
# Loss: 0.3819 | Accuracy: 0.8263
#
# Epoch 20
# Ratios - Full Input: 0.61, Landmark Only: 0.28, MFCC Only: 0.11
# Loss: 0.3757 | Accuracy: 0.8220
#
# Epoch 21
# Ratios - Full Input: 0.17, Landmark Only: 0.27, MFCC Only: 0.55
# Loss: 0.4066 | Accuracy: 0.7997
#
# Epoch 22
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.3399 | Accuracy: 0.8399
#
# Epoch 23
# Ratios - Full Input: 0.75, Landmark Only: 0.25, MFCC Only: 0.00
# Loss: 0.3135 | Accuracy: 0.8543
#
# Epoch 24
# Ratios - Full Input: 0.30, Landmark Only: 0.29, MFCC Only: 0.41
# Loss: 0.3364 | Accuracy: 0.8399
#
# Epoch 25
# Ratios - Full Input: 0.74, Landmark Only: 0.25, MFCC Only: 0.01
# Loss: 0.2740 | Accuracy: 0.8729
#
# Epoch 26
# Ratios - Full Input: 0.30, Landmark Only: 0.24, MFCC Only: 0.46
# Loss: 0.2796 | Accuracy: 0.8816
#
# Epoch 27
# Ratios - Full Input: 0.53, Landmark Only: 0.21, MFCC Only: 0.26
# Loss: 0.3213 | Accuracy: 0.8550
#
# Epoch 28
# Ratios - Full Input: 0.74, Landmark Only: 0.26, MFCC Only: 0.00
# Loss: 0.2947 | Accuracy: 0.8607
#
# Epoch 29
# Ratios - Full Input: 0.81, Landmark Only: 0.19, MFCC Only: 0.00
# Loss: 0.2580 | Accuracy: 0.8859
#
# Epoch 30
# Ratios - Full Input: 0.37, Landmark Only: 0.25, MFCC Only: 0.39
# Loss: 0.2495 | Accuracy: 0.8873
#
# Epoch 31
# Ratios - Full Input: 0.42, Landmark Only: 0.24, MFCC Only: 0.34
# Loss: 0.2864 | Accuracy: 0.8643
#
# Epoch 32
# Ratios - Full Input: 0.24, Landmark Only: 0.23, MFCC Only: 0.53
# Loss: 0.2417 | Accuracy: 0.8880
#
# Epoch 33
# Ratios - Full Input: 0.10, Landmark Only: 0.24, MFCC Only: 0.66
# Loss: 0.2321 | Accuracy: 0.8902
#
# Epoch 34
# Ratios - Full Input: 0.37, Landmark Only: 0.30, MFCC Only: 0.33
# Loss: 0.2613 | Accuracy: 0.8679
#
# Epoch 35
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.2100 | Accuracy: 0.8988
#
# Epoch 36
# Ratios - Full Input: 0.74, Landmark Only: 0.26, MFCC Only: 0.00
# Loss: 0.2427 | Accuracy: 0.8859
#
# Epoch 37
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.2067 | Accuracy: 0.9139
#
# Epoch 38
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.1960 | Accuracy: 0.9038
#
# Epoch 39
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.2107 | Accuracy: 0.9067
#
# Epoch 40
# Ratios - Full Input: 0.12, Landmark Only: 0.21, MFCC Only: 0.67
# Loss: 0.2482 | Accuracy: 0.8823
#
# Epoch 41
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.2287 | Accuracy: 0.8966
#
# Epoch 42
# Ratios - Full Input: 0.60, Landmark Only: 0.22, MFCC Only: 0.17
# Loss: 0.1842 | Accuracy: 0.9153
#
# Epoch 43
# Ratios - Full Input: 0.72, Landmark Only: 0.27, MFCC Only: 0.01
# Loss: 0.2119 | Accuracy: 0.8916
#
# Epoch 44
# Ratios - Full Input: 0.31, Landmark Only: 0.22, MFCC Only: 0.48
# Loss: 0.1977 | Accuracy: 0.8981
#
# Epoch 45
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1763 | Accuracy: 0.9153
#
# Epoch 46
# Ratios - Full Input: 0.29, Landmark Only: 0.22, MFCC Only: 0.49
# Loss: 0.1871 | Accuracy: 0.9017
#
# Epoch 47
# Ratios - Full Input: 0.25, Landmark Only: 0.28, MFCC Only: 0.47
# Loss: 0.2307 | Accuracy: 0.8593
#
# Epoch 48
# Ratios - Full Input: 0.62, Landmark Only: 0.29, MFCC Only: 0.08
# Loss: 0.2315 | Accuracy: 0.8765
#
# Epoch 49
# Ratios - Full Input: 0.77, Landmark Only: 0.21, MFCC Only: 0.03
# Loss: 0.2121 | Accuracy: 0.9045
#
# Epoch 50
# Ratios - Full Input: 0.42, Landmark Only: 0.26, MFCC Only: 0.32
# Loss: 0.2254 | Accuracy: 0.8988
#
# Epoch 51
# Ratios - Full Input: 0.12, Landmark Only: 0.21, MFCC Only: 0.67
# Loss: 0.2153 | Accuracy: 0.8880
#
# Epoch 52
# Ratios - Full Input: 0.42, Landmark Only: 0.29, MFCC Only: 0.29
# Loss: 0.2491 | Accuracy: 0.8902
#
# Epoch 53
# Ratios - Full Input: 0.70, Landmark Only: 0.28, MFCC Only: 0.03
# Loss: 0.5568 | Accuracy: 0.7193
#
# Epoch 54
# Ratios - Full Input: 0.52, Landmark Only: 0.21, MFCC Only: 0.27
# Loss: 0.6027 | Accuracy: 0.6734
#
# Epoch 55
# Ratios - Full Input: 0.81, Landmark Only: 0.19, MFCC Only: 0.00
# Loss: 0.5554 | Accuracy: 0.7172
#
# Epoch 56
# Ratios - Full Input: 0.24, Landmark Only: 0.21, MFCC Only: 0.55
# Loss: 0.5800 | Accuracy: 0.6942
#
# Epoch 57
# Ratios - Full Input: 0.14, Landmark Only: 0.23, MFCC Only: 0.62
# Loss: 0.5790 | Accuracy: 0.7193
#
# Epoch 58
# Ratios - Full Input: 0.56, Landmark Only: 0.24, MFCC Only: 0.20
# Loss: 0.5369 | Accuracy: 0.7308
#
# Epoch 59
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.4695 | Accuracy: 0.7782
#
# Epoch 60
# Ratios - Full Input: 0.40, Landmark Only: 0.22, MFCC Only: 0.38
# Loss: 0.4485 | Accuracy: 0.7789
#
# Epoch 61
# Ratios - Full Input: 0.53, Landmark Only: 0.25, MFCC Only: 0.22
# Loss: 0.3820 | Accuracy: 0.8198
#
# Epoch 62
# Ratios - Full Input: 0.81, Landmark Only: 0.19, MFCC Only: 0.00
# Loss: 0.3322 | Accuracy: 0.8471
#
# Epoch 63
# Ratios - Full Input: 0.55, Landmark Only: 0.27, MFCC Only: 0.18
# Loss: 0.3373 | Accuracy: 0.8478
#
# Epoch 64
# Ratios - Full Input: 0.24, Landmark Only: 0.25, MFCC Only: 0.51
# Loss: 0.3805 | Accuracy: 0.8076
#
# Epoch 65
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.2833 | Accuracy: 0.8758
#
# Epoch 66
# Ratios - Full Input: 0.56, Landmark Only: 0.28, MFCC Only: 0.16
# Loss: 0.2825 | Accuracy: 0.8758
#
# Epoch 67
# Ratios - Full Input: 0.18, Landmark Only: 0.26, MFCC Only: 0.56
# Loss: 0.2848 | Accuracy: 0.8579
#
# Epoch 68
# Ratios - Full Input: 0.49, Landmark Only: 0.23, MFCC Only: 0.28
# Loss: 0.2473 | Accuracy: 0.8816
#
# Epoch 69
# Ratios - Full Input: 0.75, Landmark Only: 0.25, MFCC Only: 0.00
# Loss: 0.2313 | Accuracy: 0.8995
#
# Epoch 70
# Ratios - Full Input: 0.36, Landmark Only: 0.21, MFCC Only: 0.43
# Loss: 0.2115 | Accuracy: 0.9081
#
# Epoch 71
# Ratios - Full Input: 0.47, Landmark Only: 0.26, MFCC Only: 0.27
# Loss: 0.2402 | Accuracy: 0.8887
#
# Epoch 72
# Ratios - Full Input: 0.27, Landmark Only: 0.23, MFCC Only: 0.50
# Loss: 0.2335 | Accuracy: 0.8873
#
# Epoch 73
# Ratios - Full Input: 0.18, Landmark Only: 0.28, MFCC Only: 0.55
# Loss: 0.2248 | Accuracy: 0.8973
#
# Epoch 74
# Ratios - Full Input: 0.44, Landmark Only: 0.21, MFCC Only: 0.35
# Loss: 0.1880 | Accuracy: 0.9167
#
# Epoch 75
# Ratios - Full Input: 0.41, Landmark Only: 0.22, MFCC Only: 0.37
# Loss: 0.1727 | Accuracy: 0.9210
#
# Epoch 76
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1674 | Accuracy: 0.9311
#
# Epoch 77
# Ratios - Full Input: 0.76, Landmark Only: 0.24, MFCC Only: 0.00
# Loss: 0.1833 | Accuracy: 0.9174
#
# Epoch 78
# Ratios - Full Input: 0.21, Landmark Only: 0.29, MFCC Only: 0.49
# Loss: 0.2387 | Accuracy: 0.8808
#
# Epoch 79
# Ratios - Full Input: 0.42, Landmark Only: 0.23, MFCC Only: 0.35
# Loss: 0.1838 | Accuracy: 0.9088
#
# Epoch 80
# Ratios - Full Input: 0.32, Landmark Only: 0.20, MFCC Only: 0.48
# Loss: 0.1983 | Accuracy: 0.9067
#
# Epoch 81
# Ratios - Full Input: 0.34, Landmark Only: 0.24, MFCC Only: 0.42
# Loss: 0.1862 | Accuracy: 0.9131
#
# Epoch 82
# Ratios - Full Input: 0.52, Landmark Only: 0.27, MFCC Only: 0.21
# Loss: 0.2229 | Accuracy: 0.8952
#
# Epoch 83
# Ratios - Full Input: 0.76, Landmark Only: 0.24, MFCC Only: 0.00
# Loss: 0.1558 | Accuracy: 0.9225
#
# Epoch 84
# Ratios - Full Input: 0.74, Landmark Only: 0.26, MFCC Only: 0.00
# Loss: 0.1795 | Accuracy: 0.9009
#
# Epoch 85
# Ratios - Full Input: 0.72, Landmark Only: 0.27, MFCC Only: 0.01
# Loss: 0.2134 | Accuracy: 0.9031
#
# Epoch 86
# Ratios - Full Input: 0.82, Landmark Only: 0.18, MFCC Only: 0.00
# Loss: 0.1292 | Accuracy: 0.9454
#
# Epoch 87
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1525 | Accuracy: 0.9296
#
# Epoch 88
# Ratios - Full Input: 0.21, Landmark Only: 0.22, MFCC Only: 0.57
# Loss: 0.1864 | Accuracy: 0.9110
#
# Epoch 89
# Ratios - Full Input: 0.44, Landmark Only: 0.28, MFCC Only: 0.28
# Loss: 0.2024 | Accuracy: 0.9081
#
# Epoch 90
# Ratios - Full Input: 0.75, Landmark Only: 0.25, MFCC Only: 0.00
# Loss: 0.1714 | Accuracy: 0.9182
#
# Epoch 91
# Ratios - Full Input: 0.10, Landmark Only: 0.21, MFCC Only: 0.69
# Loss: 0.1584 | Accuracy: 0.9196
#
# Epoch 92
# Ratios - Full Input: 0.10, Landmark Only: 0.28, MFCC Only: 0.61
# Loss: 0.1732 | Accuracy: 0.9131
#
# Epoch 93
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.1299 | Accuracy: 0.9296
#
# Epoch 94
# Ratios - Full Input: 0.41, Landmark Only: 0.25, MFCC Only: 0.34
# Loss: 0.1398 | Accuracy: 0.9304
#
# Epoch 95
# Ratios - Full Input: 0.46, Landmark Only: 0.27, MFCC Only: 0.27
# Loss: 0.1758 | Accuracy: 0.9067
#
# Epoch 96
# Ratios - Full Input: 0.13, Landmark Only: 0.26, MFCC Only: 0.61
# Loss: 0.1659 | Accuracy: 0.9146
#
# Epoch 97
# Ratios - Full Input: 0.76, Landmark Only: 0.24, MFCC Only: 0.00
# Loss: 0.1450 | Accuracy: 0.9282
#
# Epoch 98
# Ratios - Full Input: 0.10, Landmark Only: 0.25, MFCC Only: 0.64
# Loss: 0.1649 | Accuracy: 0.9210
#
# Epoch 99
# Ratios - Full Input: 0.26, Landmark Only: 0.24, MFCC Only: 0.50
# Loss: 0.2092 | Accuracy: 0.9038
#
# Epoch 100
# Ratios - Full Input: 0.67, Landmark Only: 0.28, MFCC Only: 0.05
# Loss: 0.1837 | Accuracy: 0.9174
#
# Epoch 101
# Ratios - Full Input: 0.43, Landmark Only: 0.22, MFCC Only: 0.35
# Loss: 0.1384 | Accuracy: 0.9340
#
# Epoch 102
# Ratios - Full Input: 0.21, Landmark Only: 0.26, MFCC Only: 0.53
# Loss: 0.1905 | Accuracy: 0.9139
#
# Epoch 103
# Ratios - Full Input: 0.81, Landmark Only: 0.19, MFCC Only: 0.00
# Loss: 0.1193 | Accuracy: 0.9526
#
# Epoch 104
# Ratios - Full Input: 0.52, Landmark Only: 0.26, MFCC Only: 0.22
# Loss: 0.1650 | Accuracy: 0.9182
#
# Epoch 105
# Ratios - Full Input: 0.68, Landmark Only: 0.23, MFCC Only: 0.09
# Loss: 0.1571 | Accuracy: 0.9203
#
# Epoch 106
# Ratios - Full Input: 0.67, Landmark Only: 0.22, MFCC Only: 0.11
# Loss: 0.1778 | Accuracy: 0.9203
#
# Epoch 107
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1441 | Accuracy: 0.9275
#
# Epoch 108
# Ratios - Full Input: 0.34, Landmark Only: 0.21, MFCC Only: 0.45
# Loss: 0.1198 | Accuracy: 0.9419
#
# Epoch 109
# Ratios - Full Input: 0.18, Landmark Only: 0.25, MFCC Only: 0.57
# Loss: 0.1625 | Accuracy: 0.9196
#
# Epoch 110
# Ratios - Full Input: 0.66, Landmark Only: 0.22, MFCC Only: 0.11
# Loss: 0.1371 | Accuracy: 0.9289
#
# Epoch 111
# Ratios - Full Input: 0.44, Landmark Only: 0.28, MFCC Only: 0.28
# Loss: 0.1822 | Accuracy: 0.9052
#
# Epoch 112
# Ratios - Full Input: 0.53, Landmark Only: 0.25, MFCC Only: 0.22
# Loss: 0.1440 | Accuracy: 0.9304
#
# Epoch 113
# Ratios - Full Input: 0.66, Landmark Only: 0.30, MFCC Only: 0.05
# Loss: 0.1765 | Accuracy: 0.9088
#
# Epoch 114
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1749 | Accuracy: 0.9196
#
# Epoch 115
# Ratios - Full Input: 0.30, Landmark Only: 0.27, MFCC Only: 0.42
# Loss: 0.1922 | Accuracy: 0.9088
#
# Epoch 116
# Ratios - Full Input: 0.57, Landmark Only: 0.23, MFCC Only: 0.19
# Loss: 0.1432 | Accuracy: 0.9239
#
# Epoch 117
# Ratios - Full Input: 0.12, Landmark Only: 0.28, MFCC Only: 0.60
# Loss: 0.1730 | Accuracy: 0.9139
#
# Epoch 118
# Ratios - Full Input: 0.34, Landmark Only: 0.24, MFCC Only: 0.42
# Loss: 0.1899 | Accuracy: 0.9067
#
# Epoch 119
# Ratios - Full Input: 0.73, Landmark Only: 0.27, MFCC Only: 0.00
# Loss: 0.1775 | Accuracy: 0.9002
#
# Epoch 120
# Ratios - Full Input: 0.42, Landmark Only: 0.28, MFCC Only: 0.30
# Loss: 0.1743 | Accuracy: 0.9110
#
# Epoch 121
# Ratios - Full Input: 0.28, Landmark Only: 0.30, MFCC Only: 0.43
# Loss: 0.1811 | Accuracy: 0.9052
#
# Epoch 122
# Ratios - Full Input: 0.75, Landmark Only: 0.25, MFCC Only: 0.00
# Loss: 0.1314 | Accuracy: 0.9383
#
# Epoch 123
# Ratios - Full Input: 0.30, Landmark Only: 0.24, MFCC Only: 0.45
# Loss: 0.1495 | Accuracy: 0.9246
#
# Epoch 124
# Ratios - Full Input: 0.79, Landmark Only: 0.21, MFCC Only: 0.00
# Loss: 0.1885 | Accuracy: 0.9189
#
# Epoch 125
# Ratios - Full Input: 0.79, Landmark Only: 0.21, MFCC Only: 0.00
# Loss: 0.1736 | Accuracy: 0.9225
#
# Epoch 126
# Ratios - Full Input: 0.46, Landmark Only: 0.30, MFCC Only: 0.24
# Loss: 0.2151 | Accuracy: 0.8880
#
# Epoch 127
# Ratios - Full Input: 0.15, Landmark Only: 0.27, MFCC Only: 0.58
# Loss: 0.1791 | Accuracy: 0.9139
#
# Epoch 128
# Ratios - Full Input: 0.57, Landmark Only: 0.22, MFCC Only: 0.21
# Loss: 0.1465 | Accuracy: 0.9275
#
# Epoch 129
# Ratios - Full Input: 0.40, Landmark Only: 0.25, MFCC Only: 0.35
# Loss: 0.1524 | Accuracy: 0.9225
#
# Epoch 130
# Ratios - Full Input: 0.24, Landmark Only: 0.24, MFCC Only: 0.52
# Loss: 0.1536 | Accuracy: 0.9203
#
# Epoch 131
# Ratios - Full Input: 0.82, Landmark Only: 0.18, MFCC Only: 0.00
# Loss: 0.1269 | Accuracy: 0.9282
#
# Epoch 132
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.1245 | Accuracy: 0.9411
#
# Epoch 133
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1364 | Accuracy: 0.9368
#
# Epoch 134
# Ratios - Full Input: 0.33, Landmark Only: 0.26, MFCC Only: 0.41
# Loss: 0.1476 | Accuracy: 0.9246
#
# Epoch 135
# Ratios - Full Input: 0.29, Landmark Only: 0.25, MFCC Only: 0.46
# Loss: 0.1516 | Accuracy: 0.9253
#
# Epoch 136
# Ratios - Full Input: 0.18, Landmark Only: 0.23, MFCC Only: 0.59
# Loss: 0.1363 | Accuracy: 0.9261
#
# Epoch 137
# Ratios - Full Input: 0.39, Landmark Only: 0.30, MFCC Only: 0.31
# Loss: 0.1719 | Accuracy: 0.9031
#
# Epoch 138
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1352 | Accuracy: 0.9268
#
# Epoch 139
# Ratios - Full Input: 0.71, Landmark Only: 0.21, MFCC Only: 0.08
# Loss: 0.1441 | Accuracy: 0.9253
#
# Epoch 140
# Ratios - Full Input: 0.14, Landmark Only: 0.29, MFCC Only: 0.57
# Loss: 0.1729 | Accuracy: 0.9153
#
# Epoch 141
# Ratios - Full Input: 0.36, Landmark Only: 0.26, MFCC Only: 0.38
# Loss: 0.1499 | Accuracy: 0.9239
#
# Epoch 142
# Ratios - Full Input: 0.72, Landmark Only: 0.26, MFCC Only: 0.03
# Loss: 0.1432 | Accuracy: 0.9246
#
# Epoch 143
# Ratios - Full Input: 0.69, Landmark Only: 0.22, MFCC Only: 0.09
# Loss: 0.1243 | Accuracy: 0.9419
#
# Epoch 144
# Ratios - Full Input: 0.26, Landmark Only: 0.21, MFCC Only: 0.53
# Loss: 0.1194 | Accuracy: 0.9383
#
# Epoch 145
# Ratios - Full Input: 0.44, Landmark Only: 0.22, MFCC Only: 0.34
# Loss: 0.1303 | Accuracy: 0.9332
#
# Epoch 146
# Ratios - Full Input: 0.50, Landmark Only: 0.23, MFCC Only: 0.26
# Loss: 0.1271 | Accuracy: 0.9361
#
# Epoch 147
# Ratios - Full Input: 0.48, Landmark Only: 0.30, MFCC Only: 0.22
# Loss: 0.1681 | Accuracy: 0.9095
#
# Epoch 148
# Ratios - Full Input: 0.19, Landmark Only: 0.22, MFCC Only: 0.59
# Loss: 0.1230 | Accuracy: 0.9325
#
# Epoch 149
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1287 | Accuracy: 0.9354
#
# Epoch 150
# Ratios - Full Input: 0.76, Landmark Only: 0.24, MFCC Only: 0.00
# Loss: 0.1243 | Accuracy: 0.9426
#
# Epoch 151
# Ratios - Full Input: 0.54, Landmark Only: 0.29, MFCC Only: 0.17
# Loss: 0.1626 | Accuracy: 0.9196
#
# Epoch 152
# Ratios - Full Input: 0.35, Landmark Only: 0.26, MFCC Only: 0.39
# Loss: 0.1838 | Accuracy: 0.9081
#
# Epoch 153
# Ratios - Full Input: 0.42, Landmark Only: 0.24, MFCC Only: 0.34
# Loss: 0.1537 | Accuracy: 0.9311
#
# Epoch 154
# Ratios - Full Input: 0.75, Landmark Only: 0.25, MFCC Only: 0.00
# Loss: 0.1609 | Accuracy: 0.9182
#
# Epoch 155
# Ratios - Full Input: 0.13, Landmark Only: 0.24, MFCC Only: 0.62
# Loss: 0.1794 | Accuracy: 0.9117
#
# Epoch 156
# Ratios - Full Input: 0.11, Landmark Only: 0.24, MFCC Only: 0.65
# Loss: 0.1672 | Accuracy: 0.9196
#
# Epoch 157
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1486 | Accuracy: 0.9282
#
# Epoch 158
# Ratios - Full Input: 0.50, Landmark Only: 0.26, MFCC Only: 0.24
# Loss: 0.1472 | Accuracy: 0.9268
#
# Epoch 159
# Ratios - Full Input: 0.54, Landmark Only: 0.24, MFCC Only: 0.22
# Loss: 0.1265 | Accuracy: 0.9404
#
# Epoch 160
# Ratios - Full Input: 0.55, Landmark Only: 0.22, MFCC Only: 0.23
# Loss: 0.1255 | Accuracy: 0.9368
#
# Epoch 161
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.1175 | Accuracy: 0.9361
#
# Epoch 162
# Ratios - Full Input: 0.74, Landmark Only: 0.26, MFCC Only: 0.00
# Loss: 0.1357 | Accuracy: 0.9375
#
# Epoch 163
# Ratios - Full Input: 0.71, Landmark Only: 0.29, MFCC Only: 0.00
# Loss: 0.1666 | Accuracy: 0.9117
#
# Epoch 164
# Ratios - Full Input: 0.45, Landmark Only: 0.28, MFCC Only: 0.27
# Loss: 0.1625 | Accuracy: 0.9117
#
# Epoch 165
# Ratios - Full Input: 0.15, Landmark Only: 0.30, MFCC Only: 0.55
# Loss: 0.2231 | Accuracy: 0.9038
#
# Epoch 166
# Ratios - Full Input: 0.73, Landmark Only: 0.25, MFCC Only: 0.02
# Loss: 0.2001 | Accuracy: 0.9174
#
# Epoch 167
# Ratios - Full Input: 0.39, Landmark Only: 0.21, MFCC Only: 0.39
# Loss: 0.1576 | Accuracy: 0.9311
#
# Epoch 168
# Ratios - Full Input: 0.64, Landmark Only: 0.27, MFCC Only: 0.09
# Loss: 0.1640 | Accuracy: 0.9174
#
# Epoch 169
# Ratios - Full Input: 0.82, Landmark Only: 0.18, MFCC Only: 0.00
# Loss: 0.1092 | Accuracy: 0.9483
#
# Epoch 170
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1241 | Accuracy: 0.9411
#
# Epoch 171
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1303 | Accuracy: 0.9332
#
# Epoch 172
# Ratios - Full Input: 0.66, Landmark Only: 0.28, MFCC Only: 0.06
# Loss: 0.1441 | Accuracy: 0.9304
#
# Epoch 173
# Ratios - Full Input: 0.46, Landmark Only: 0.22, MFCC Only: 0.32
# Loss: 0.1226 | Accuracy: 0.9419
#
# Epoch 174
# Ratios - Full Input: 0.74, Landmark Only: 0.26, MFCC Only: 0.00
# Loss: 0.1447 | Accuracy: 0.9261
#
# Epoch 175
# Ratios - Full Input: 0.18, Landmark Only: 0.24, MFCC Only: 0.58
# Loss: 0.1445 | Accuracy: 0.9282
#
# Epoch 176
# Ratios - Full Input: 0.67, Landmark Only: 0.29, MFCC Only: 0.04
# Loss: 0.1587 | Accuracy: 0.9189
#
# Epoch 177
# Ratios - Full Input: 0.13, Landmark Only: 0.27, MFCC Only: 0.60
# Loss: 0.1381 | Accuracy: 0.9325
#
# Epoch 178
# Ratios - Full Input: 0.44, Landmark Only: 0.29, MFCC Only: 0.27
# Loss: 0.1628 | Accuracy: 0.9218
#
# Epoch 179
# Ratios - Full Input: 0.82, Landmark Only: 0.18, MFCC Only: 0.00
# Loss: 0.1186 | Accuracy: 0.9383
#
# Epoch 180
# Ratios - Full Input: 0.48, Landmark Only: 0.26, MFCC Only: 0.25
# Loss: 0.1723 | Accuracy: 0.9174
#
# Epoch 181
# Ratios - Full Input: 0.79, Landmark Only: 0.21, MFCC Only: 0.00
# Loss: 0.1480 | Accuracy: 0.9296
#
# Epoch 182
# Ratios - Full Input: 0.51, Landmark Only: 0.29, MFCC Only: 0.20
# Loss: 0.1649 | Accuracy: 0.9153
#
# Epoch 183
# Ratios - Full Input: 0.56, Landmark Only: 0.22, MFCC Only: 0.23
# Loss: 0.1185 | Accuracy: 0.9447
#
# Epoch 184
# Ratios - Full Input: 0.59, Landmark Only: 0.20, MFCC Only: 0.21
# Loss: 0.1027 | Accuracy: 0.9469
#
# Epoch 185
# Ratios - Full Input: 0.42, Landmark Only: 0.24, MFCC Only: 0.34
# Loss: 0.1258 | Accuracy: 0.9304
#
# Epoch 186
# Ratios - Full Input: 0.33, Landmark Only: 0.23, MFCC Only: 0.44
# Loss: 0.1213 | Accuracy: 0.9383
#
# Epoch 187
# Ratios - Full Input: 0.37, Landmark Only: 0.23, MFCC Only: 0.40
# Loss: 0.1158 | Accuracy: 0.9404
#
# Epoch 188
# Ratios - Full Input: 0.49, Landmark Only: 0.20, MFCC Only: 0.30
# Loss: 0.1109 | Accuracy: 0.9505
#
# Epoch 189
# Ratios - Full Input: 0.19, Landmark Only: 0.29, MFCC Only: 0.53
# Loss: 0.1476 | Accuracy: 0.9325
#
# Epoch 190
# Ratios - Full Input: 0.76, Landmark Only: 0.24, MFCC Only: 0.00
# Loss: 0.1319 | Accuracy: 0.9368
#
# Epoch 191
# Ratios - Full Input: 0.70, Landmark Only: 0.26, MFCC Only: 0.04
# Loss: 0.1409 | Accuracy: 0.9253
#
# Epoch 192
# Ratios - Full Input: 0.32, Landmark Only: 0.22, MFCC Only: 0.46
# Loss: 0.1149 | Accuracy: 0.9454
#
# Epoch 193
# Ratios - Full Input: 0.51, Landmark Only: 0.28, MFCC Only: 0.21
# Loss: 0.1549 | Accuracy: 0.9225
#
# Epoch 194
# Ratios - Full Input: 0.76, Landmark Only: 0.24, MFCC Only: 0.00
# Loss: 0.1312 | Accuracy: 0.9253
#
# Epoch 195
# Ratios - Full Input: 0.82, Landmark Only: 0.18, MFCC Only: 0.00
# Loss: 0.0961 | Accuracy: 0.9541
#
# Epoch 196
# Ratios - Full Input: 0.15, Landmark Only: 0.22, MFCC Only: 0.63
# Loss: 0.1257 | Accuracy: 0.9375
#
# Epoch 197
# Ratios - Full Input: 0.75, Landmark Only: 0.22, MFCC Only: 0.02
# Loss: 0.1346 | Accuracy: 0.9253
#
# Epoch 198
# Ratios - Full Input: 0.37, Landmark Only: 0.30, MFCC Only: 0.33
# Loss: 0.2036 | Accuracy: 0.9124
#
# Epoch 199
# Ratios - Full Input: 0.19, Landmark Only: 0.29, MFCC Only: 0.52
# Loss: 0.1737 | Accuracy: 0.9167
#
# Epoch 200
# Ratios - Full Input: 0.35, Landmark Only: 0.29, MFCC Only: 0.36
# Loss: 0.2073 | Accuracy: 0.9160
#
# Epoch 201
# Ratios - Full Input: 0.52, Landmark Only: 0.24, MFCC Only: 0.24
# Loss: 0.1360 | Accuracy: 0.9318
#
# Epoch 202
# Ratios - Full Input: 0.63, Landmark Only: 0.29, MFCC Only: 0.08
# Loss: 0.1832 | Accuracy: 0.9117
#
# Epoch 203
# Ratios - Full Input: 0.23, Landmark Only: 0.22, MFCC Only: 0.55
# Loss: 0.1360 | Accuracy: 0.9296
#
# Epoch 204
# Ratios - Full Input: 0.73, Landmark Only: 0.26, MFCC Only: 0.00
# Loss: 0.1444 | Accuracy: 0.9246
#
# Epoch 205
# Ratios - Full Input: 0.74, Landmark Only: 0.25, MFCC Only: 0.01
# Loss: 0.1291 | Accuracy: 0.9282
#
# Epoch 206
# Ratios - Full Input: 0.82, Landmark Only: 0.18, MFCC Only: 0.00
# Loss: 0.1061 | Accuracy: 0.9512
#
# Epoch 207
# Ratios - Full Input: 0.18, Landmark Only: 0.24, MFCC Only: 0.58
# Loss: 0.1417 | Accuracy: 0.9239
#
# Epoch 208
# Ratios - Full Input: 0.13, Landmark Only: 0.24, MFCC Only: 0.63
# Loss: 0.1421 | Accuracy: 0.9232
#
# Epoch 209
# Ratios - Full Input: 0.36, Landmark Only: 0.29, MFCC Only: 0.35
# Loss: 0.1574 | Accuracy: 0.9210
#
# Epoch 210
# Ratios - Full Input: 0.51, Landmark Only: 0.29, MFCC Only: 0.20
# Loss: 0.1516 | Accuracy: 0.9282
#
# Epoch 211
# Ratios - Full Input: 0.32, Landmark Only: 0.22, MFCC Only: 0.47
# Loss: 0.1231 | Accuracy: 0.9368
#
# Epoch 212
# Ratios - Full Input: 0.79, Landmark Only: 0.21, MFCC Only: 0.00
# Loss: 0.1174 | Accuracy: 0.9361
#
# Epoch 213
# Ratios - Full Input: 0.20, Landmark Only: 0.25, MFCC Only: 0.55
# Loss: 0.1586 | Accuracy: 0.9311
#
# Epoch 214
# Ratios - Full Input: 0.23, Landmark Only: 0.23, MFCC Only: 0.53
# Loss: 0.1628 | Accuracy: 0.9189
#
# Epoch 215
# Ratios - Full Input: 0.28, Landmark Only: 0.26, MFCC Only: 0.46
# Loss: 0.1489 | Accuracy: 0.9289
#
# Epoch 216
# Ratios - Full Input: 0.11, Landmark Only: 0.29, MFCC Only: 0.60
# Loss: 0.1945 | Accuracy: 0.9146
#
# Epoch 217
# Ratios - Full Input: 0.22, Landmark Only: 0.24, MFCC Only: 0.54
# Loss: 0.1467 | Accuracy: 0.9397
#
# Epoch 218
# Ratios - Full Input: 0.74, Landmark Only: 0.26, MFCC Only: 0.00
# Loss: 0.1461 | Accuracy: 0.9239
#
# Epoch 219
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1153 | Accuracy: 0.9483
#
# Epoch 220
# Ratios - Full Input: 0.29, Landmark Only: 0.21, MFCC Only: 0.50
# Loss: 0.1397 | Accuracy: 0.9282
#
# Epoch 221
# Ratios - Full Input: 0.12, Landmark Only: 0.23, MFCC Only: 0.65
# Loss: 0.1375 | Accuracy: 0.9311
#
# Epoch 222
# Ratios - Full Input: 0.25, Landmark Only: 0.21, MFCC Only: 0.53
# Loss: 0.1222 | Accuracy: 0.9433
#
# Epoch 223
# Ratios - Full Input: 0.49, Landmark Only: 0.28, MFCC Only: 0.23
# Loss: 0.1507 | Accuracy: 0.9196
#
# Epoch 224
# Ratios - Full Input: 0.36, Landmark Only: 0.25, MFCC Only: 0.40
# Loss: 0.1442 | Accuracy: 0.9347
#
# Epoch 225
# Ratios - Full Input: 0.11, Landmark Only: 0.24, MFCC Only: 0.65
# Loss: 0.1727 | Accuracy: 0.9253
#
# Epoch 226
# Ratios - Full Input: 0.82, Landmark Only: 0.18, MFCC Only: 0.00
# Loss: 0.1078 | Accuracy: 0.9497
#
# Epoch 227
# Ratios - Full Input: 0.38, Landmark Only: 0.29, MFCC Only: 0.33
# Loss: 0.1708 | Accuracy: 0.9160
#
# Epoch 228
# Ratios - Full Input: 0.72, Landmark Only: 0.28, MFCC Only: 0.00
# Loss: 0.1489 | Accuracy: 0.9153
#
# Epoch 229
# Ratios - Full Input: 0.24, Landmark Only: 0.23, MFCC Only: 0.53
# Loss: 0.1233 | Accuracy: 0.9390
#
# Epoch 230
# Ratios - Full Input: 0.12, Landmark Only: 0.20, MFCC Only: 0.68
# Loss: 0.1181 | Accuracy: 0.9375
#
# Epoch 231
# Ratios - Full Input: 0.46, Landmark Only: 0.26, MFCC Only: 0.28
# Loss: 0.1457 | Accuracy: 0.9325
#
# Epoch 232
# Ratios - Full Input: 0.29, Landmark Only: 0.28, MFCC Only: 0.43
# Loss: 0.2049 | Accuracy: 0.9153
#
# Epoch 233
# Ratios - Full Input: 0.27, Landmark Only: 0.28, MFCC Only: 0.45
# Loss: 0.1627 | Accuracy: 0.9261
#
# Epoch 234
# Ratios - Full Input: 0.61, Landmark Only: 0.21, MFCC Only: 0.18
# Loss: 0.1186 | Accuracy: 0.9419
#
# Epoch 235
# Ratios - Full Input: 0.69, Landmark Only: 0.24, MFCC Only: 0.07
# Loss: 0.1321 | Accuracy: 0.9397
#
# Epoch 236
# Ratios - Full Input: 0.15, Landmark Only: 0.22, MFCC Only: 0.63
# Loss: 0.1226 | Accuracy: 0.9383
#
# Epoch 237
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1171 | Accuracy: 0.9411
#
# Epoch 238
# Ratios - Full Input: 0.28, Landmark Only: 0.24, MFCC Only: 0.48
# Loss: 0.1318 | Accuracy: 0.9261
#
# Epoch 239
# Ratios - Full Input: 0.30, Landmark Only: 0.20, MFCC Only: 0.50
# Loss: 0.1056 | Accuracy: 0.9476
#
# Epoch 240
# Ratios - Full Input: 0.13, Landmark Only: 0.20, MFCC Only: 0.67
# Loss: 0.1346 | Accuracy: 0.9354
#
# Epoch 241
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1579 | Accuracy: 0.9225
#
# Epoch 242
# Ratios - Full Input: 0.31, Landmark Only: 0.21, MFCC Only: 0.48
# Loss: 0.1115 | Accuracy: 0.9440
#
# Epoch 243
# Ratios - Full Input: 0.44, Landmark Only: 0.25, MFCC Only: 0.31
# Loss: 0.1337 | Accuracy: 0.9332
#
# Epoch 244
# Ratios - Full Input: 0.47, Landmark Only: 0.20, MFCC Only: 0.33
# Loss: 0.1021 | Accuracy: 0.9555
#
# Epoch 245
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.1209 | Accuracy: 0.9426
#
# Epoch 246
# Ratios - Full Input: 0.35, Landmark Only: 0.25, MFCC Only: 0.41
# Loss: 0.1313 | Accuracy: 0.9411
#
# Epoch 247
# Ratios - Full Input: 0.19, Landmark Only: 0.30, MFCC Only: 0.51
# Loss: 0.1536 | Accuracy: 0.9239
#
# Epoch 248
# Ratios - Full Input: 0.79, Landmark Only: 0.21, MFCC Only: 0.00
# Loss: 0.1128 | Accuracy: 0.9490
#
# Epoch 249
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.0979 | Accuracy: 0.9512
#
# Epoch 250
# Ratios - Full Input: 0.34, Landmark Only: 0.24, MFCC Only: 0.42
# Loss: 0.1284 | Accuracy: 0.9397
#
# Epoch 251
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1115 | Accuracy: 0.9462
#
# Epoch 252
# Ratios - Full Input: 0.37, Landmark Only: 0.22, MFCC Only: 0.41
# Loss: 0.1012 | Accuracy: 0.9519
#
# Epoch 253
# Ratios - Full Input: 0.44, Landmark Only: 0.26, MFCC Only: 0.30
# Loss: 0.1354 | Accuracy: 0.9325
#
# Epoch 254
# Ratios - Full Input: 0.74, Landmark Only: 0.24, MFCC Only: 0.01
# Loss: 0.1285 | Accuracy: 0.9383
#
# Epoch 255
# Ratios - Full Input: 0.68, Landmark Only: 0.28, MFCC Only: 0.04
# Loss: 0.1445 | Accuracy: 0.9282
#
# Epoch 256
# Ratios - Full Input: 0.15, Landmark Only: 0.28, MFCC Only: 0.57
# Loss: 0.1490 | Accuracy: 0.9268
#
# Epoch 257
# Ratios - Full Input: 0.78, Landmark Only: 0.21, MFCC Only: 0.01
# Loss: 0.1159 | Accuracy: 0.9404
#
# Epoch 258
# Ratios - Full Input: 0.12, Landmark Only: 0.24, MFCC Only: 0.64
# Loss: 0.1304 | Accuracy: 0.9340
#
# Epoch 259
# Ratios - Full Input: 0.72, Landmark Only: 0.22, MFCC Only: 0.07
# Loss: 0.1171 | Accuracy: 0.9462
#
# Epoch 260
# Ratios - Full Input: 0.79, Landmark Only: 0.21, MFCC Only: 0.00
# Loss: 0.1191 | Accuracy: 0.9375
#
# Epoch 261
# Ratios - Full Input: 0.76, Landmark Only: 0.24, MFCC Only: 0.00
# Loss: 0.1418 | Accuracy: 0.9239
#
# Epoch 262
# Ratios - Full Input: 0.71, Landmark Only: 0.27, MFCC Only: 0.02
# Loss: 0.1470 | Accuracy: 0.9174
#
# Epoch 263
# Ratios - Full Input: 0.26, Landmark Only: 0.22, MFCC Only: 0.52
# Loss: 0.1123 | Accuracy: 0.9440
#
# Epoch 264
# Ratios - Full Input: 0.74, Landmark Only: 0.26, MFCC Only: 0.00
# Loss: 0.1445 | Accuracy: 0.9289
#
# Epoch 265
# Ratios - Full Input: 0.81, Landmark Only: 0.19, MFCC Only: 0.00
# Loss: 0.1030 | Accuracy: 0.9519
#
# Epoch 266
# Ratios - Full Input: 0.18, Landmark Only: 0.28, MFCC Only: 0.54
# Loss: 0.1384 | Accuracy: 0.9325
#
# Epoch 267
# Ratios - Full Input: 0.25, Landmark Only: 0.30, MFCC Only: 0.46
# Loss: 0.1543 | Accuracy: 0.9225
#
# Epoch 268
# Ratios - Full Input: 0.47, Landmark Only: 0.21, MFCC Only: 0.31
# Loss: 0.1096 | Accuracy: 0.9497
#
# Epoch 269
# Ratios - Full Input: 0.66, Landmark Only: 0.21, MFCC Only: 0.13
# Loss: 0.1097 | Accuracy: 0.9505
#
# Epoch 270
# Ratios - Full Input: 0.73, Landmark Only: 0.27, MFCC Only: 0.00
# Loss: 0.1361 | Accuracy: 0.9325
#
# Epoch 271
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.1074 | Accuracy: 0.9490
#
# Epoch 272
# Ratios - Full Input: 0.24, Landmark Only: 0.29, MFCC Only: 0.47
# Loss: 0.1382 | Accuracy: 0.9354
#
# Epoch 273
# Ratios - Full Input: 0.48, Landmark Only: 0.28, MFCC Only: 0.24
# Loss: 0.1475 | Accuracy: 0.9318
#
# Epoch 274
# Ratios - Full Input: 0.22, Landmark Only: 0.26, MFCC Only: 0.52
# Loss: 0.1389 | Accuracy: 0.9325
#
# Epoch 275
# Ratios - Full Input: 0.11, Landmark Only: 0.25, MFCC Only: 0.64
# Loss: 0.1273 | Accuracy: 0.9375
#
# Epoch 276
# Ratios - Full Input: 0.44, Landmark Only: 0.26, MFCC Only: 0.30
# Loss: 0.1385 | Accuracy: 0.9375
#
# Epoch 277
# Ratios - Full Input: 0.35, Landmark Only: 0.26, MFCC Only: 0.39
# Loss: 0.1397 | Accuracy: 0.9289
#
# Epoch 278
# Ratios - Full Input: 0.25, Landmark Only: 0.27, MFCC Only: 0.48
# Loss: 0.1390 | Accuracy: 0.9325
#
# Epoch 279
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1164 | Accuracy: 0.9426
#
# Epoch 280
# Ratios - Full Input: 0.46, Landmark Only: 0.26, MFCC Only: 0.28
# Loss: 0.1237 | Accuracy: 0.9476
#
# Epoch 281
# Ratios - Full Input: 0.33, Landmark Only: 0.26, MFCC Only: 0.41
# Loss: 0.1343 | Accuracy: 0.9311
#
# Epoch 282
# Ratios - Full Input: 0.30, Landmark Only: 0.23, MFCC Only: 0.47
# Loss: 0.1116 | Accuracy: 0.9454
#
# Epoch 283
# Ratios - Full Input: 0.81, Landmark Only: 0.19, MFCC Only: 0.00
# Loss: 0.0846 | Accuracy: 0.9598
#
# Epoch 284
# Ratios - Full Input: 0.25, Landmark Only: 0.23, MFCC Only: 0.52
# Loss: 0.1280 | Accuracy: 0.9404
#
# Epoch 285
# Ratios - Full Input: 0.29, Landmark Only: 0.23, MFCC Only: 0.48
# Loss: 0.1164 | Accuracy: 0.9419
#
# Epoch 286
# Ratios - Full Input: 0.17, Landmark Only: 0.22, MFCC Only: 0.61
# Loss: 0.1151 | Accuracy: 0.9397
#
# Epoch 287
# Ratios - Full Input: 0.79, Landmark Only: 0.21, MFCC Only: 0.00
# Loss: 0.1054 | Accuracy: 0.9497
#
# Epoch 288
# Ratios - Full Input: 0.27, Landmark Only: 0.29, MFCC Only: 0.43
# Loss: 0.1517 | Accuracy: 0.9253
#
# Epoch 289
# Ratios - Full Input: 0.56, Landmark Only: 0.26, MFCC Only: 0.18
# Loss: 0.1309 | Accuracy: 0.9404
#
# Epoch 290
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.1025 | Accuracy: 0.9512
#
# Epoch 291
# Ratios - Full Input: 0.15, Landmark Only: 0.22, MFCC Only: 0.63
# Loss: 0.1105 | Accuracy: 0.9505
#
# Epoch 292
# Ratios - Full Input: 0.76, Landmark Only: 0.24, MFCC Only: 0.00
# Loss: 0.1196 | Accuracy: 0.9447
#
# Epoch 293
# Ratios - Full Input: 0.79, Landmark Only: 0.21, MFCC Only: 0.00
# Loss: 0.1039 | Accuracy: 0.9490
#
# Epoch 294
# Ratios - Full Input: 0.35, Landmark Only: 0.29, MFCC Only: 0.37
# Loss: 0.1362 | Accuracy: 0.9325
#
# Epoch 295
# Ratios - Full Input: 0.51, Landmark Only: 0.28, MFCC Only: 0.21
# Loss: 0.2728 | Accuracy: 0.8966
#
# Epoch 296
# Ratios - Full Input: 0.49, Landmark Only: 0.29, MFCC Only: 0.22
# Loss: 0.2317 | Accuracy: 0.9031
#
# Epoch 297
# Ratios - Full Input: 0.58, Landmark Only: 0.28, MFCC Only: 0.14
# Loss: 0.1784 | Accuracy: 0.9232
#
# Epoch 298
# Ratios - Full Input: 0.31, Landmark Only: 0.29, MFCC Only: 0.40
# Loss: 0.1701 | Accuracy: 0.9232
#
# Epoch 299
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1284 | Accuracy: 0.9454
#
# Epoch 300
# Ratios - Full Input: 0.12, Landmark Only: 0.21, MFCC Only: 0.67
# Loss: 0.1177 | Accuracy: 0.9426
#
# Epoch 301
# Ratios - Full Input: 0.79, Landmark Only: 0.21, MFCC Only: 0.00
# Loss: 0.1127 | Accuracy: 0.9462
#
# Epoch 302
# Ratios - Full Input: 0.55, Landmark Only: 0.26, MFCC Only: 0.19
# Loss: 0.1314 | Accuracy: 0.9426
#
# Epoch 303
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1096 | Accuracy: 0.9483
#
# Epoch 304
# Ratios - Full Input: 0.70, Landmark Only: 0.27, MFCC Only: 0.03
# Loss: 0.1549 | Accuracy: 0.9210
#
# Epoch 305
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1197 | Accuracy: 0.9469
#
# Epoch 306
# Ratios - Full Input: 0.19, Landmark Only: 0.22, MFCC Only: 0.58
# Loss: 0.1548 | Accuracy: 0.9354
#
# Epoch 307
# Ratios - Full Input: 0.61, Landmark Only: 0.28, MFCC Only: 0.11
# Loss: 0.1438 | Accuracy: 0.9311
#
# Epoch 308
# Ratios - Full Input: 0.15, Landmark Only: 0.23, MFCC Only: 0.62
# Loss: 0.1348 | Accuracy: 0.9347
#
# Epoch 309
# Ratios - Full Input: 0.49, Landmark Only: 0.24, MFCC Only: 0.27
# Loss: 0.1288 | Accuracy: 0.9440
#
# Epoch 310
# Ratios - Full Input: 0.20, Landmark Only: 0.28, MFCC Only: 0.52
# Loss: 0.1555 | Accuracy: 0.9311
#
# Epoch 311
# Ratios - Full Input: 0.42, Landmark Only: 0.25, MFCC Only: 0.33
# Loss: 0.1151 | Accuracy: 0.9490
#
# Epoch 312
# Ratios - Full Input: 0.11, Landmark Only: 0.23, MFCC Only: 0.67
# Loss: 0.1129 | Accuracy: 0.9526
#
# Epoch 313
# Ratios - Full Input: 0.31, Landmark Only: 0.26, MFCC Only: 0.43
# Loss: 0.1322 | Accuracy: 0.9433
#
# Epoch 314
# Ratios - Full Input: 0.63, Landmark Only: 0.24, MFCC Only: 0.13
# Loss: 0.1216 | Accuracy: 0.9347
#
# Epoch 315
# Ratios - Full Input: 0.26, Landmark Only: 0.25, MFCC Only: 0.49
# Loss: 0.1271 | Accuracy: 0.9340
#
# Epoch 316
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1242 | Accuracy: 0.9419
#
# Epoch 317
# Ratios - Full Input: 0.20, Landmark Only: 0.27, MFCC Only: 0.53
# Loss: 0.1437 | Accuracy: 0.9261
#
# Epoch 318
# Ratios - Full Input: 0.33, Landmark Only: 0.27, MFCC Only: 0.40
# Loss: 0.1222 | Accuracy: 0.9454
#
# Epoch 319
# Ratios - Full Input: 0.21, Landmark Only: 0.30, MFCC Only: 0.49
# Loss: 0.1527 | Accuracy: 0.9289
#
# Epoch 320
# Ratios - Full Input: 0.19, Landmark Only: 0.28, MFCC Only: 0.54
# Loss: 0.1412 | Accuracy: 0.9261
#
# Epoch 321
# Ratios - Full Input: 0.73, Landmark Only: 0.23, MFCC Only: 0.04
# Loss: 0.1119 | Accuracy: 0.9505
#
# Epoch 322
# Ratios - Full Input: 0.69, Landmark Only: 0.30, MFCC Only: 0.01
# Loss: 0.1571 | Accuracy: 0.9253
#
# Epoch 323
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1206 | Accuracy: 0.9462
#
# Epoch 324
# Ratios - Full Input: 0.33, Landmark Only: 0.24, MFCC Only: 0.43
# Loss: 0.1271 | Accuracy: 0.9411
#
# Epoch 325
# Ratios - Full Input: 0.72, Landmark Only: 0.24, MFCC Only: 0.04
# Loss: 0.1213 | Accuracy: 0.9426
#
# Epoch 326
# Ratios - Full Input: 0.81, Landmark Only: 0.19, MFCC Only: 0.00
# Loss: 0.0857 | Accuracy: 0.9605
#
# Epoch 327
# Ratios - Full Input: 0.81, Landmark Only: 0.19, MFCC Only: 0.00
# Loss: 0.0851 | Accuracy: 0.9605
#
# Epoch 328
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1173 | Accuracy: 0.9426
#
# Epoch 329
# Ratios - Full Input: 0.27, Landmark Only: 0.21, MFCC Only: 0.52
# Loss: 0.0995 | Accuracy: 0.9526
#
# Epoch 330
# Ratios - Full Input: 0.23, Landmark Only: 0.27, MFCC Only: 0.51
# Loss: 0.1226 | Accuracy: 0.9390
#
# Epoch 331
# Ratios - Full Input: 0.44, Landmark Only: 0.21, MFCC Only: 0.35
# Loss: 0.1123 | Accuracy: 0.9483
#
# Epoch 332
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1496 | Accuracy: 0.9404
#
# Epoch 333
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1580 | Accuracy: 0.9282
#
# Epoch 334
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1260 | Accuracy: 0.9397
#
# Epoch 335
# Ratios - Full Input: 0.31, Landmark Only: 0.25, MFCC Only: 0.44
# Loss: 0.1484 | Accuracy: 0.9347
#
# Epoch 336
# Ratios - Full Input: 0.19, Landmark Only: 0.30, MFCC Only: 0.51
# Loss: 0.1468 | Accuracy: 0.9361
#
# Epoch 337
# Ratios - Full Input: 0.44, Landmark Only: 0.27, MFCC Only: 0.29
# Loss: 0.1515 | Accuracy: 0.9311
#
# Epoch 338
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.1102 | Accuracy: 0.9505
#
# Epoch 339
# Ratios - Full Input: 0.50, Landmark Only: 0.23, MFCC Only: 0.27
# Loss: 0.1203 | Accuracy: 0.9404
#
# Epoch 340
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.0957 | Accuracy: 0.9584
#
# Epoch 341
# Ratios - Full Input: 0.31, Landmark Only: 0.24, MFCC Only: 0.45
# Loss: 0.1095 | Accuracy: 0.9483
#
# Epoch 342
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.0869 | Accuracy: 0.9605
#
# Epoch 343
# Ratios - Full Input: 0.33, Landmark Only: 0.27, MFCC Only: 0.40
# Loss: 0.1246 | Accuracy: 0.9390
#
# Epoch 344
# Ratios - Full Input: 0.39, Landmark Only: 0.23, MFCC Only: 0.38
# Loss: 0.1028 | Accuracy: 0.9555
#
# Epoch 345
# Ratios - Full Input: 0.79, Landmark Only: 0.21, MFCC Only: 0.00
# Loss: 0.1132 | Accuracy: 0.9541
#
# Epoch 346
# Ratios - Full Input: 0.20, Landmark Only: 0.23, MFCC Only: 0.57
# Loss: 0.1002 | Accuracy: 0.9584
#
# Epoch 347
# Ratios - Full Input: 0.33, Landmark Only: 0.26, MFCC Only: 0.41
# Loss: 0.1254 | Accuracy: 0.9454
#
# Epoch 348
# Ratios - Full Input: 0.38, Landmark Only: 0.30, MFCC Only: 0.32
# Loss: 0.1490 | Accuracy: 0.9289
#
# Epoch 349
# Ratios - Full Input: 0.50, Landmark Only: 0.22, MFCC Only: 0.28
# Loss: 0.1070 | Accuracy: 0.9419
#
# Epoch 350
# Ratios - Full Input: 0.19, Landmark Only: 0.26, MFCC Only: 0.55
# Loss: 0.1280 | Accuracy: 0.9397
#
# Epoch 351
# Ratios - Full Input: 0.18, Landmark Only: 0.28, MFCC Only: 0.54
# Loss: 0.1438 | Accuracy: 0.9325
#
# Epoch 352
# Ratios - Full Input: 0.66, Landmark Only: 0.29, MFCC Only: 0.04
# Loss: 0.1464 | Accuracy: 0.9311
#
# Epoch 353
# Ratios - Full Input: 0.57, Landmark Only: 0.23, MFCC Only: 0.20
# Loss: 0.1115 | Accuracy: 0.9476
#
# Epoch 354
# Ratios - Full Input: 0.25, Landmark Only: 0.24, MFCC Only: 0.50
# Loss: 0.1081 | Accuracy: 0.9490
#
# Epoch 355
# Ratios - Full Input: 0.47, Landmark Only: 0.22, MFCC Only: 0.31
# Loss: 0.1051 | Accuracy: 0.9526
#
# Epoch 356
# Ratios - Full Input: 0.54, Landmark Only: 0.24, MFCC Only: 0.23
# Loss: 0.1123 | Accuracy: 0.9490
#
# Epoch 357
# Ratios - Full Input: 0.73, Landmark Only: 0.27, MFCC Only: 0.00
# Loss: 0.1289 | Accuracy: 0.9426
#
# Epoch 358
# Ratios - Full Input: 0.49, Landmark Only: 0.29, MFCC Only: 0.22
# Loss: 0.1407 | Accuracy: 0.9347
#
# Epoch 359
# Ratios - Full Input: 0.54, Landmark Only: 0.25, MFCC Only: 0.22
# Loss: 0.1178 | Accuracy: 0.9497
#
# Epoch 360
# Ratios - Full Input: 0.38, Landmark Only: 0.21, MFCC Only: 0.41
# Loss: 0.1084 | Accuracy: 0.9497
#
# Epoch 361
# Ratios - Full Input: 0.63, Landmark Only: 0.26, MFCC Only: 0.11
# Loss: 0.1159 | Accuracy: 0.9512
#
# Epoch 362
# Ratios - Full Input: 0.50, Landmark Only: 0.27, MFCC Only: 0.23
# Loss: 0.1371 | Accuracy: 0.9354
#
# Epoch 363
# Ratios - Full Input: 0.73, Landmark Only: 0.22, MFCC Only: 0.05
# Loss: 0.0946 | Accuracy: 0.9620
#
# Epoch 364
# Ratios - Full Input: 0.58, Landmark Only: 0.25, MFCC Only: 0.17
# Loss: 0.1099 | Accuracy: 0.9519
#
# Epoch 365
# Ratios - Full Input: 0.75, Landmark Only: 0.25, MFCC Only: 0.00
# Loss: 0.1166 | Accuracy: 0.9497
#
# Epoch 366
# Ratios - Full Input: 0.79, Landmark Only: 0.21, MFCC Only: 0.00
# Loss: 0.0974 | Accuracy: 0.9541
#
# Epoch 367
# Ratios - Full Input: 0.73, Landmark Only: 0.27, MFCC Only: 0.00
# Loss: 0.1354 | Accuracy: 0.9347
#
# Epoch 368
# Ratios - Full Input: 0.32, Landmark Only: 0.29, MFCC Only: 0.39
# Loss: 0.1365 | Accuracy: 0.9411
#
# Epoch 369
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.0879 | Accuracy: 0.9655
#
# Epoch 370
# Ratios - Full Input: 0.81, Landmark Only: 0.19, MFCC Only: 0.00
# Loss: 0.0850 | Accuracy: 0.9627
#
# Epoch 371
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1109 | Accuracy: 0.9440
#
# Epoch 372
# Ratios - Full Input: 0.49, Landmark Only: 0.27, MFCC Only: 0.23
# Loss: 0.1352 | Accuracy: 0.9325
#
# Epoch 373
# Ratios - Full Input: 0.27, Landmark Only: 0.24, MFCC Only: 0.49
# Loss: 0.1205 | Accuracy: 0.9440
#
# Epoch 374
# Ratios - Full Input: 0.70, Landmark Only: 0.27, MFCC Only: 0.02
# Loss: 0.1386 | Accuracy: 0.9340
#
# Epoch 375
# Ratios - Full Input: 0.49, Landmark Only: 0.29, MFCC Only: 0.21
# Loss: 0.1282 | Accuracy: 0.9404
#
# Epoch 376
# Ratios - Full Input: 0.55, Landmark Only: 0.27, MFCC Only: 0.18
# Loss: 0.1417 | Accuracy: 0.9318
#
# Epoch 377
# Ratios - Full Input: 0.64, Landmark Only: 0.21, MFCC Only: 0.15
# Loss: 0.0925 | Accuracy: 0.9555
#
# Epoch 378
# Ratios - Full Input: 0.37, Landmark Only: 0.25, MFCC Only: 0.38
# Loss: 0.1092 | Accuracy: 0.9519
#
# Epoch 379
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1159 | Accuracy: 0.9490
#
# Epoch 380
# Ratios - Full Input: 0.36, Landmark Only: 0.30, MFCC Only: 0.35
# Loss: 0.1440 | Accuracy: 0.9397
#
# Epoch 381
# Ratios - Full Input: 0.71, Landmark Only: 0.29, MFCC Only: 0.00
# Loss: 0.1258 | Accuracy: 0.9375
#
# Epoch 382
# Ratios - Full Input: 0.79, Landmark Only: 0.21, MFCC Only: 0.00
# Loss: 0.0974 | Accuracy: 0.9569
#
# Epoch 383
# Ratios - Full Input: 0.64, Landmark Only: 0.24, MFCC Only: 0.13
# Loss: 0.1079 | Accuracy: 0.9469
#
# Epoch 384
# Ratios - Full Input: 0.75, Landmark Only: 0.25, MFCC Only: 0.00
# Loss: 0.1113 | Accuracy: 0.9512
#
# Epoch 385
# Ratios - Full Input: 0.76, Landmark Only: 0.24, MFCC Only: 0.00
# Loss: 0.1249 | Accuracy: 0.9397
#
# Epoch 386
# Ratios - Full Input: 0.76, Landmark Only: 0.24, MFCC Only: 0.00
# Loss: 0.1178 | Accuracy: 0.9469
#
# Epoch 387
# Ratios - Full Input: 0.54, Landmark Only: 0.26, MFCC Only: 0.19
# Loss: 0.1144 | Accuracy: 0.9505
#
# Epoch 388
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1070 | Accuracy: 0.9562
#
# Epoch 389
# Ratios - Full Input: 0.37, Landmark Only: 0.27, MFCC Only: 0.36
# Loss: 0.1298 | Accuracy: 0.9390
#
# Epoch 390
# Ratios - Full Input: 0.37, Landmark Only: 0.27, MFCC Only: 0.36
# Loss: 0.1213 | Accuracy: 0.9447
#
# Epoch 391
# Ratios - Full Input: 0.39, Landmark Only: 0.24, MFCC Only: 0.37
# Loss: 0.1178 | Accuracy: 0.9433
#
# Epoch 392
# Ratios - Full Input: 0.35, Landmark Only: 0.22, MFCC Only: 0.42
# Loss: 0.1167 | Accuracy: 0.9476
#
# Epoch 393
# Ratios - Full Input: 0.14, Landmark Only: 0.20, MFCC Only: 0.66
# Loss: 0.1086 | Accuracy: 0.9476
#
# Epoch 394
# Ratios - Full Input: 0.37, Landmark Only: 0.21, MFCC Only: 0.42
# Loss: 0.1010 | Accuracy: 0.9548
#
# Epoch 395
# Ratios - Full Input: 0.50, Landmark Only: 0.21, MFCC Only: 0.29
# Loss: 0.1036 | Accuracy: 0.9541
#
# Epoch 396
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.0896 | Accuracy: 0.9627
#
# Epoch 397
# Ratios - Full Input: 0.83, Landmark Only: 0.17, MFCC Only: 0.00
# Loss: 0.0976 | Accuracy: 0.9548
#
# Epoch 398
# Ratios - Full Input: 0.53, Landmark Only: 0.29, MFCC Only: 0.18
# Loss: 0.1319 | Accuracy: 0.9426
#
# Epoch 399
# Ratios - Full Input: 0.13, Landmark Only: 0.25, MFCC Only: 0.62
# Loss: 0.1215 | Accuracy: 0.9426
#
# Epoch 400
# Ratios - Full Input: 0.20, Landmark Only: 0.27, MFCC Only: 0.54
# Loss: 0.1247 | Accuracy: 0.9440
#
# Epoch 401
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.0982 | Accuracy: 0.9548
#
# Epoch 402
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1051 | Accuracy: 0.9519
#
# Epoch 403
# Ratios - Full Input: 0.52, Landmark Only: 0.27, MFCC Only: 0.21
# Loss: 0.1253 | Accuracy: 0.9440
#
# Epoch 404
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.1093 | Accuracy: 0.9497
#
# Epoch 405
# Ratios - Full Input: 0.13, Landmark Only: 0.28, MFCC Only: 0.59
# Loss: 0.1382 | Accuracy: 0.9354
#
# Epoch 406
# Ratios - Full Input: 0.18, Landmark Only: 0.23, MFCC Only: 0.59
# Loss: 0.1238 | Accuracy: 0.9383
#
# Epoch 407
# Ratios - Full Input: 0.42, Landmark Only: 0.24, MFCC Only: 0.35
# Loss: 0.1103 | Accuracy: 0.9497
#
# Epoch 408
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.0988 | Accuracy: 0.9562
#
# Epoch 409
# Ratios - Full Input: 0.37, Landmark Only: 0.22, MFCC Only: 0.41
# Loss: 0.1013 | Accuracy: 0.9533
#
# Epoch 410
# Ratios - Full Input: 0.26, Landmark Only: 0.28, MFCC Only: 0.46
# Loss: 0.1369 | Accuracy: 0.9296
#
# Epoch 411
# Ratios - Full Input: 0.81, Landmark Only: 0.19, MFCC Only: 0.00
# Loss: 0.0969 | Accuracy: 0.9548
#
# Epoch 412
# Ratios - Full Input: 0.74, Landmark Only: 0.25, MFCC Only: 0.01
# Loss: 0.1106 | Accuracy: 0.9512
#
# Epoch 413
# Ratios - Full Input: 0.75, Landmark Only: 0.25, MFCC Only: 0.00
# Loss: 0.1208 | Accuracy: 0.9426
#
# Epoch 414
# Ratios - Full Input: 0.46, Landmark Only: 0.26, MFCC Only: 0.29
# Loss: 0.1212 | Accuracy: 0.9505
#
# Epoch 415
# Ratios - Full Input: 0.65, Landmark Only: 0.29, MFCC Only: 0.07
# Loss: 0.1321 | Accuracy: 0.9411
#
# Epoch 416
# Ratios - Full Input: 0.41, Landmark Only: 0.28, MFCC Only: 0.31
# Loss: 0.1373 | Accuracy: 0.9361
#
# Epoch 417
# Ratios - Full Input: 0.60, Landmark Only: 0.22, MFCC Only: 0.18
# Loss: 0.0953 | Accuracy: 0.9541
#
# Epoch 418
# Ratios - Full Input: 0.49, Landmark Only: 0.30, MFCC Only: 0.21
# Loss: 0.1472 | Accuracy: 0.9311
#
# Epoch 419
# Ratios - Full Input: 0.41, Landmark Only: 0.28, MFCC Only: 0.31
# Loss: 0.1366 | Accuracy: 0.9419
#
# Epoch 420
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.1037 | Accuracy: 0.9541
#
# Epoch 421
# Ratios - Full Input: 0.68, Landmark Only: 0.27, MFCC Only: 0.05
# Loss: 0.1259 | Accuracy: 0.9462
#
# Epoch 422
# Ratios - Full Input: 0.25, Landmark Only: 0.24, MFCC Only: 0.52
# Loss: 0.1172 | Accuracy: 0.9447
#
# Epoch 423
# Ratios - Full Input: 0.74, Landmark Only: 0.26, MFCC Only: 0.00
# Loss: 0.1158 | Accuracy: 0.9447
#
# Epoch 424
# Ratios - Full Input: 0.72, Landmark Only: 0.28, MFCC Only: 0.00
# Loss: 0.1181 | Accuracy: 0.9490
#
# Epoch 425
# Ratios - Full Input: 0.73, Landmark Only: 0.27, MFCC Only: 0.00
# Loss: 0.1382 | Accuracy: 0.9375
#
# Epoch 426
# Ratios - Full Input: 0.16, Landmark Only: 0.21, MFCC Only: 0.63
# Loss: 0.1047 | Accuracy: 0.9562
#
# Epoch 427
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.1607 | Accuracy: 0.9426
#
# Epoch 428
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.1523 | Accuracy: 0.9332
#
# Epoch 429
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1351 | Accuracy: 0.9433
#
# Epoch 430
# Ratios - Full Input: 0.59, Landmark Only: 0.26, MFCC Only: 0.15
# Loss: 0.1285 | Accuracy: 0.9483
#
# Epoch 431
# Ratios - Full Input: 0.50, Landmark Only: 0.28, MFCC Only: 0.21
# Loss: 0.1657 | Accuracy: 0.9261
#
# Epoch 432
# Ratios - Full Input: 0.61, Landmark Only: 0.21, MFCC Only: 0.19
# Loss: 0.1263 | Accuracy: 0.9469
#
# Epoch 433
# Ratios - Full Input: 0.21, Landmark Only: 0.28, MFCC Only: 0.51
# Loss: 0.1437 | Accuracy: 0.9375
#
# Epoch 434
# Ratios - Full Input: 0.27, Landmark Only: 0.21, MFCC Only: 0.52
# Loss: 0.0997 | Accuracy: 0.9627
#
# Epoch 435
# Ratios - Full Input: 0.55, Landmark Only: 0.27, MFCC Only: 0.18
# Loss: 0.1176 | Accuracy: 0.9469
#
# Epoch 436
# Ratios - Full Input: 0.71, Landmark Only: 0.23, MFCC Only: 0.06
# Loss: 0.0982 | Accuracy: 0.9591
#
# Epoch 437
# Ratios - Full Input: 0.66, Landmark Only: 0.21, MFCC Only: 0.14
# Loss: 0.0998 | Accuracy: 0.9584
#
# Epoch 438
# Ratios - Full Input: 0.55, Landmark Only: 0.23, MFCC Only: 0.22
# Loss: 0.1096 | Accuracy: 0.9526
#
# Epoch 439
# Ratios - Full Input: 0.14, Landmark Only: 0.22, MFCC Only: 0.64
# Loss: 0.1077 | Accuracy: 0.9462
#
# Epoch 440
# Ratios - Full Input: 0.60, Landmark Only: 0.20, MFCC Only: 0.19
# Loss: 0.1021 | Accuracy: 0.9533
#
# Epoch 441
# Ratios - Full Input: 0.32, Landmark Only: 0.21, MFCC Only: 0.48
# Loss: 0.0897 | Accuracy: 0.9605
#
# Epoch 442
# Ratios - Full Input: 0.73, Landmark Only: 0.27, MFCC Only: 0.00
# Loss: 0.1374 | Accuracy: 0.9476
#
# Epoch 443
# Ratios - Full Input: 0.12, Landmark Only: 0.27, MFCC Only: 0.61
# Loss: 0.1189 | Accuracy: 0.9512
#
# Epoch 444
# Ratios - Full Input: 0.83, Landmark Only: 0.17, MFCC Only: 0.00
# Loss: 0.0756 | Accuracy: 0.9634
#
# Epoch 445
# Ratios - Full Input: 0.75, Landmark Only: 0.25, MFCC Only: 0.00
# Loss: 0.1232 | Accuracy: 0.9383
#
# Epoch 446
# Ratios - Full Input: 0.63, Landmark Only: 0.26, MFCC Only: 0.11
# Loss: 0.1170 | Accuracy: 0.9454
#
# Epoch 447
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.0978 | Accuracy: 0.9555
#
# Epoch 448
# Ratios - Full Input: 0.23, Landmark Only: 0.29, MFCC Only: 0.47
# Loss: 0.1502 | Accuracy: 0.9354
#
# Epoch 449
# Ratios - Full Input: 0.82, Landmark Only: 0.18, MFCC Only: 0.00
# Loss: 0.0916 | Accuracy: 0.9598
#
# Epoch 450
# Ratios - Full Input: 0.80, Landmark Only: 0.20, MFCC Only: 0.00
# Loss: 0.1143 | Accuracy: 0.9519
#
# Epoch 451
# Ratios - Full Input: 0.53, Landmark Only: 0.29, MFCC Only: 0.18
# Loss: 0.1443 | Accuracy: 0.9318
#
# Epoch 452
# Ratios - Full Input: 0.75, Landmark Only: 0.25, MFCC Only: 0.00
# Loss: 0.1219 | Accuracy: 0.9411
#
# Epoch 453
# Ratios - Full Input: 0.16, Landmark Only: 0.29, MFCC Only: 0.54
# Loss: 0.1462 | Accuracy: 0.9383
#
# Epoch 454
# Ratios - Full Input: 0.47, Landmark Only: 0.28, MFCC Only: 0.25
# Loss: 0.1217 | Accuracy: 0.9462
#
# Epoch 455
# Ratios - Full Input: 0.40, Landmark Only: 0.29, MFCC Only: 0.31
# Loss: 0.1436 | Accuracy: 0.9354
#
# Epoch 456
# Ratios - Full Input: 0.58, Landmark Only: 0.27, MFCC Only: 0.15
# Loss: 0.1080 | Accuracy: 0.9555
#
# Epoch 457
# Ratios - Full Input: 0.51, Landmark Only: 0.21, MFCC Only: 0.28
# Loss: 0.0949 | Accuracy: 0.9591
#
# Epoch 458
# Ratios - Full Input: 0.31, Landmark Only: 0.28, MFCC Only: 0.41
# Loss: 0.1248 | Accuracy: 0.9411
#
# Epoch 459
# Ratios - Full Input: 0.71, Landmark Only: 0.20, MFCC Only: 0.09
# Loss: 0.0933 | Accuracy: 0.9562
#
# Epoch 460
# Ratios - Full Input: 0.64, Landmark Only: 0.22, MFCC Only: 0.13
# Loss: 0.0917 | Accuracy: 0.9648
#
# Epoch 461
# Ratios - Full Input: 0.30, Landmark Only: 0.24, MFCC Only: 0.46
# Loss: 0.1100 | Accuracy: 0.9526
#
# Epoch 462
# Ratios - Full Input: 0.74, Landmark Only: 0.26, MFCC Only: 0.00
# Loss: 0.1387 | Accuracy: 0.9368
#
# Epoch 463
# Ratios - Full Input: 0.32, Landmark Only: 0.25, MFCC Only: 0.43
# Loss: 0.1675 | Accuracy: 0.9210
#
# Epoch 464
# Ratios - Full Input: 0.23, Landmark Only: 0.20, MFCC Only: 0.56
# Loss: 0.1132 | Accuracy: 0.9483
#
# Epoch 465
# Ratios - Full Input: 0.26, Landmark Only: 0.27, MFCC Only: 0.47
# Loss: 0.1316 | Accuracy: 0.9426
#
# Epoch 466
# Ratios - Full Input: 0.74, Landmark Only: 0.26, MFCC Only: 0.00
# Loss: 0.1221 | Accuracy: 0.9483
#
# Epoch 467
# Ratios - Full Input: 0.48, Landmark Only: 0.20, MFCC Only: 0.32
# Loss: 0.0974 | Accuracy: 0.9576
#
# Epoch 468
# Ratios - Full Input: 0.58, Landmark Only: 0.25, MFCC Only: 0.17
# Loss: 0.1314 | Accuracy: 0.9454
#
# Epoch 469
# Ratios - Full Input: 0.46, Landmark Only: 0.26, MFCC Only: 0.28
# Loss: 0.1347 | Accuracy: 0.9440
#
# Epoch 470
# Ratios - Full Input: 0.64, Landmark Only: 0.23, MFCC Only: 0.13
# Loss: 0.1077 | Accuracy: 0.9512
#
# Epoch 471
# Ratios - Full Input: 0.52, Landmark Only: 0.21, MFCC Only: 0.27
# Loss: 0.0937 | Accuracy: 0.9576
#
# Epoch 472
# Ratios - Full Input: 0.42, Landmark Only: 0.29, MFCC Only: 0.29
# Loss: 0.1429 | Accuracy: 0.9426
#
# Epoch 473
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1204 | Accuracy: 0.9390
#
# Epoch 474
# Ratios - Full Input: 0.61, Landmark Only: 0.27, MFCC Only: 0.11
# Loss: 0.1203 | Accuracy: 0.9505
#
# Epoch 475
# Ratios - Full Input: 0.81, Landmark Only: 0.19, MFCC Only: 0.00
# Loss: 0.0931 | Accuracy: 0.9548
#
# Epoch 476
# Ratios - Full Input: 0.78, Landmark Only: 0.22, MFCC Only: 0.00
# Loss: 0.1000 | Accuracy: 0.9598
#
# Epoch 477
# Ratios - Full Input: 0.52, Landmark Only: 0.23, MFCC Only: 0.26
# Loss: 0.1152 | Accuracy: 0.9462
#
# Epoch 478
# Ratios - Full Input: 0.46, Landmark Only: 0.26, MFCC Only: 0.28
# Loss: 0.1215 | Accuracy: 0.9411
#
# Epoch 479
# Ratios - Full Input: 0.70, Landmark Only: 0.24, MFCC Only: 0.06
# Loss: 0.1121 | Accuracy: 0.9476
#
# Epoch 480
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.1026 | Accuracy: 0.9576
#
# Epoch 481
# Ratios - Full Input: 0.37, Landmark Only: 0.28, MFCC Only: 0.35
# Loss: 0.1303 | Accuracy: 0.9447
#
# Epoch 482
# Ratios - Full Input: 0.62, Landmark Only: 0.22, MFCC Only: 0.15
# Loss: 0.0985 | Accuracy: 0.9598
#
# Epoch 483
# Ratios - Full Input: 0.25, Landmark Only: 0.25, MFCC Only: 0.51
# Loss: 0.1074 | Accuracy: 0.9505
#
# Epoch 484
# Ratios - Full Input: 0.42, Landmark Only: 0.28, MFCC Only: 0.30
# Loss: 0.1290 | Accuracy: 0.9390
#
# Epoch 485
# Ratios - Full Input: 0.34, Landmark Only: 0.24, MFCC Only: 0.41
# Loss: 0.1038 | Accuracy: 0.9562
#
# Epoch 486
# Ratios - Full Input: 0.76, Landmark Only: 0.24, MFCC Only: 0.00
# Loss: 0.1109 | Accuracy: 0.9526
#
# Epoch 487
# Ratios - Full Input: 0.39, Landmark Only: 0.30, MFCC Only: 0.31
# Loss: 0.1464 | Accuracy: 0.9318
#
# Epoch 488
# Ratios - Full Input: 0.45, Landmark Only: 0.20, MFCC Only: 0.35
# Loss: 0.0800 | Accuracy: 0.9713
#
# Epoch 489
# Ratios - Full Input: 0.45, Landmark Only: 0.28, MFCC Only: 0.27
# Loss: 0.1252 | Accuracy: 0.9469
#
# Epoch 490
# Ratios - Full Input: 0.54, Landmark Only: 0.22, MFCC Only: 0.24
# Loss: 0.0953 | Accuracy: 0.9620
#
# Epoch 491
# Ratios - Full Input: 0.77, Landmark Only: 0.23, MFCC Only: 0.00
# Loss: 0.0879 | Accuracy: 0.9620
#
# Epoch 492
# Ratios - Full Input: 0.77, Landmark Only: 0.20, MFCC Only: 0.03
# Loss: 0.0985 | Accuracy: 0.9548
#
# Epoch 493
# Ratios - Full Input: 0.11, Landmark Only: 0.29, MFCC Only: 0.60
# Loss: 0.1339 | Accuracy: 0.9411
#
# Epoch 494
# Ratios - Full Input: 0.37, Landmark Only: 0.23, MFCC Only: 0.40
# Loss: 0.1036 | Accuracy: 0.9512
#
# Epoch 495
# Ratios - Full Input: 0.76, Landmark Only: 0.24, MFCC Only: 0.00
# Loss: 0.0981 | Accuracy: 0.9598
#
# Epoch 496
# Ratios - Full Input: 0.73, Landmark Only: 0.26, MFCC Only: 0.00
# Loss: 0.1182 | Accuracy: 0.9490
#
# Epoch 497
# Ratios - Full Input: 0.16, Landmark Only: 0.29, MFCC Only: 0.56
# Loss: 0.1323 | Accuracy: 0.9375
#
# Epoch 498
# Ratios - Full Input: 0.28, Landmark Only: 0.28, MFCC Only: 0.45
# Loss: 0.1258 | Accuracy: 0.9476
#
# Epoch 499
# Ratios - Full Input: 0.15, Landmark Only: 0.21, MFCC Only: 0.64
# Loss: 0.1026 | Accuracy: 0.9526
#
# Epoch 500
# Ratios - Full Input: 0.64, Landmark Only: 0.27, MFCC Only: 0.08
# Loss: 0.1351 | Accuracy: 0.9375

# %%
pip install visualkeras
# Out:
# Requirement already satisfied: visualkeras in /usr/local/lib/python3.11/dist-packages (0.1.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (11.1.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (1.26.4)
# Requirement already satisfied: aggdraw>=1.3.11 in /usr/local/lib/python3.11/dist-packages (from visualkeras) (1.3.19)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.18.1->visualkeras) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.1->visualkeras) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.18.1->visualkeras) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.1->visualkeras) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.18.1->visualkeras) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.18.1->visualkeras) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import visualkeras
import matplotlib.pyplot as plt
from PIL import Image

# Save model diagram to file
visualkeras.layered_view(model2, legend=True, draw_volume=True, to_file='model.png')

# Display it inline
img = Image.open('model.png')
plt.figure(figsize=(10, 5))
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/visualkeras/layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")

# %%
# ✅ Import libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    roc_curve, auc, confusion_matrix, ConfusionMatrixDisplay,
    precision_recall_curve, classification_report
)

# ✅ Predict for all three conditions
y_pred_full = model2.predict([X_test_landmark, X_test_mfcc]).flatten()

dummy_mfcc = np.zeros_like(X_test_mfcc)
y_pred_landmark = model2.predict([X_test_landmark, dummy_mfcc]).flatten()

dummy_landmark = np.zeros_like(X_test_landmark)
y_pred_mfcc = model2.predict([dummy_landmark, X_test_mfcc]).flatten()

# Convert to binary labels
y_true = y_test
y_label_full = (y_pred_full >= 0.5).astype(int)
y_label_landmark = (y_pred_landmark >= 0.5).astype(int)
y_label_mfcc = (y_pred_mfcc >= 0.5).astype(int)

# ✅ Helper function for all plots & metrics
def plot_all_metrics(y_true, y_prob, y_label, title):
    # --- ROC ---
    fpr, tpr, _ = roc_curve(y_true, y_prob)
    roc_auc = auc(fpr, tpr)
    plt.figure(figsize=(6, 4))  # keep same box
    plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.3f}", linewidth=7)  # thicker line
    plt.plot([0, 1], [0, 1], 'k--', linewidth=1.5)
    plt.title(f"{title} ROC Curve")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend()
    plt.show()

    # --- Confusion Matrix (counts) ---
    cm = confusion_matrix(y_true, y_label)
    fig, ax = plt.subplots(figsize=(4, 4))  # fixed size
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap='Blues', ax=ax, colorbar=False)
    ax.set_title(f"{title} Confusion Matrix (Counts)")
    for label in ax.texts:
        label.set_fontsize(30)  # larger text
    plt.show()

    # --- Confusion Matrix (percentage) ---
    cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.figure(figsize=(4, 4))  # fixed size
    sns.heatmap(cm_percent, annot=True, fmt=".2%", cmap='Blues',
                cbar=False, annot_kws={"size": 30})  # bigger font
    plt.title(f"{title} Confusion Matrix (Percentage)")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    # --- Precision-Recall Curve ---
    prec, rec, _ = precision_recall_curve(y_true, y_prob)
    plt.figure(figsize=(6, 4))
    plt.plot(rec, prec, linewidth=2.5)
    plt.title(f"{title} Precision-Recall Curve")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.show()

    # --- Probability Distribution ---
    sns.histplot(y_prob, bins=30, kde=True)
    plt.title(f"{title} Predicted Probability Distribution")
    plt.xlabel("Predicted Probability")
    plt.ylabel("Frequency")
    plt.show()

    # --- Cluster Plot (Correct vs Incorrect) ---
    is_correct = y_true == y_label

    plt.figure(figsize=(6, 4))
    plt.scatter(y_prob[is_correct], y_true[is_correct],
                c='green', label='Correct', alpha=0.6)
    plt.scatter(y_prob[~is_correct], y_true[~is_correct],
                c='red', label='Incorrect', alpha=0.6)
    plt.title(f"{title} Prediction Cluster\n(Green=Correct, Red=Incorrect)")
    plt.xlabel("Predicted Probability")
    plt.ylabel("True Label")
    plt.legend()
    plt.show()

    # --- Overall Metrics (macro & weighted) ---
    print(f"\n{title} Overall Metrics:\n")
    report = classification_report(y_true, y_label, output_dict=True)
    print(f"Macro Average:")
    print(f"  Precision: {report['macro avg']['precision']:.4f}")
    print(f"  Recall:    {report['macro avg']['recall']:.4f}")
    print(f"  F1-Score:  {report['macro avg']['f1-score']:.4f}")
    print(f"\nWeighted Average:")
    print(f"  Precision: {report['weighted avg']['precision']:.4f}")
    print(f"  Recall:    {report['weighted avg']['recall']:.4f}")
    print(f"  F1-Score:  {report['weighted avg']['f1-score']:.4f}")


# ✅ Plot & print for each case
plot_all_metrics(y_true, y_pred_full, y_label_full, "Full Input")
plot_all_metrics(y_true, y_pred_landmark, y_label_landmark, "Landmark Only")
plot_all_metrics(y_true, y_pred_mfcc, y_label_mfcc, "MFCC Only")

# ✅ Also re-print model.evaluate for consistency
loss, acc = model2.evaluate([X_test_landmark, X_test_mfcc], y_test, verbose=0)
loss_landmark, acc_landmark = model2.evaluate([X_test_landmark, dummy_mfcc], y_test, verbose=0)
loss_mfcc, acc_mfcc = model2.evaluate([dummy_landmark, X_test_mfcc], y_test, verbose=0)

print(f"\nFull Test Set Accuracy: {acc:.4f}")
print(f"Facial Landmark Only Test Set Accuracy: {acc_landmark:.4f}")
print(f"MFCC Only Test Set Accuracy: {acc_mfcc:.4f}")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Full Input Overall Metrics:
#
# Macro Average:
#   Precision: 0.9648
#   Recall:    0.9648
#   F1-Score:  0.9648
#
# Weighted Average:
#   Precision: 0.9648
#   Recall:    0.9648
#   F1-Score:  0.9648
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Landmark Only Overall Metrics:
#
# Macro Average:
#   Precision: 0.7562
#   Recall:    0.7389
#   F1-Score:  0.7343
#
# Weighted Average:
#   Precision: 0.7563
#   Recall:    0.7387
#   F1-Score:  0.7342
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# MFCC Only Overall Metrics:
#
# Macro Average:
#   Precision: 0.9598
#   Recall:    0.9598
#   F1-Score:  0.9598
#
# Weighted Average:
#   Precision: 0.9598
#   Recall:    0.9598
#   F1-Score:  0.9598
#
# Full Test Set Accuracy: 0.9648
# Facial Landmark Only Test Set Accuracy: 0.7387
# MFCC Only Test Set Accuracy: 0.9598

# %%
loss, acc = model2.evaluate([X_test_landmark, X_test_mfcc], y_test)
print(f"Full Test Set Accuracy: {acc:.4f}")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9500 - loss: 0.3084
# Full Test Set Accuracy: 0.9648

# %%
dummy_mfcc = np.zeros_like(X_test_mfcc)

loss_landmark, acc_landmark = model2.evaluate([X_test_landmark, dummy_mfcc], y_test)
print(f" Facial Landmark Only Test Set Accuracy: {acc_landmark:.4f}")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7208 - loss: 0.5226
#  Facial Landmark Only Test Set Accuracy: 0.7387

# %%
dummy_landmark = np.zeros_like(X_test_landmark)

loss_mfcc, acc_mfcc = model2.evaluate([dummy_landmark, X_test_mfcc], y_test)
print(f" MFCC Only Test Set Accuracy: {acc_mfcc:.4f}")
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9465 - loss: 0.3415
#  MFCC Only Test Set Accuracy: 0.9598
